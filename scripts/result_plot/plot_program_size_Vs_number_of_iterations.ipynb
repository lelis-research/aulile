# %% [markdown]
# ## Processing the log files of A-BUS and keep last runs logs only

# %%
import os
import re
from datetime import datetime, timedelta
import glob

def parse_time_taken(time_str):
    """Parse the 'Time taken' string into a timedelta object."""
    hours, minutes, seconds = map(float, time_str.split(':'))
    return timedelta(hours=hours, minutes=minutes, seconds=seconds)

def parse_line_for_timestamp(line):
    """Extract timestamp from a line if present."""
    timestamp_regex = r'\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d+'
    match = re.search(timestamp_regex, line)
    if match:
        return datetime.strptime(match.group(), '%Y-%m-%d %H:%M:%S.%f')
    return None

def process_file(file_path):
    lines_to_keep = []
    start_time = None
    end_time = None
    current_time = None
    is_successful = False

    with open(file_path, 'r') as file:
        for line in file:
            if 'Time taken:' in line:
                time_taken_str = line.split('Time taken:')[1].strip()
                time_taken = parse_time_taken(time_taken_str)
                end_time = parse_line_for_timestamp(previous_line)
                start_time = end_time - time_taken - timedelta(seconds=100)
                print(f"Start time: {start_time}, End time: {end_time}")
            
            if 'Success' in line:
                is_successful = True

            previous_line = line
    
    if is_successful:
        with open(file_path, 'r') as file:
            # Go back to the start of the file and read it again
            if start_time and end_time:
                for line in file:
                    new_current_time = parse_line_for_timestamp(line)
                    current_time = new_current_time if new_current_time else current_time
                    if current_time and start_time <= current_time <= end_time:
                        lines_to_keep.append(line)

    # Write the filtered lines back to the file
    # with open(file_path, 'w') as file:
    #     file.writelines(lines_to_keep)
    
    # go to the parent directory and create a new directory called 'filtered' if it doesn't exist
    # and write the filtered file there with the same name
    parent_dir = os.path.dirname(file_path)
    # go one level up to the parent directory
    parent_dir = os.path.dirname(parent_dir)
    filtered_dir = os.path.join(parent_dir, 'filtered')
    if not os.path.exists(filtered_dir):
        os.makedirs(filtered_dir)
    filtered_file_path = os.path.join(filtered_dir, os.path.basename(file_path))
    with open(filtered_file_path, 'w') as file:
        file.writelines(lines_to_keep)
    

def process_files_in_directory(directory_path, file_pattern):
    for file_path in glob.glob(os.path.join(directory_path, file_pattern)):
        print(f"Processing file: {file_path}")
        process_file(file_path)

# %%
# BUS _ sygus benchmarks
# Replace these with your directory path and file pattern
directory_path = '../../logs/bus_89_Jan10_2024/augmented'
file_pattern = '*_A-BUS_*_1.log'
process_files_in_directory(directory_path, file_pattern)

# %%
# BUS _ 38 benchmarks
directory_path = '../../logs/bus_38_Jan10_2024/augmented'
file_pattern = '*_A-BUS_*_1.log'
process_files_in_directory(directory_path, file_pattern)

# %%
# BUSTLE _ sygus benchmarks
# Replace these with your directory path and file pattern
directory_path = '../../logs/bustle_89/augmented'
file_pattern = '*_A-Bustle_*_1_*.log'
process_files_in_directory(directory_path, file_pattern)

# %%
# BUSTLE _ sygus benchmarks
# Replace these with your directory path and file pattern
directory_path = '../../logs/bustle_38/augmented'
file_pattern = '*_A-Bustle_*_1_*.log'
process_files_in_directory(directory_path, file_pattern)

# %% [markdown]
# ## Count the number of Iterations in the log file

# %%
import os

def count_iterations(dirs, augmented):
    result_dict = {}

    for key, value in dirs.items():
        sub_dirs = [augmented]
        for sub_dir in sub_dirs:
            # get all the files in the directory
            files = os.listdir(value + sub_dir)
            # for each file
            for file in files:
                # find the run from the file name if Bustle/Bee in the file name
                # bustle file name patterns: <key>_A-Bustle_<id>_<augmented/non_augmented>_<run>.log
                # bee file name patterns: <key>_A-Bee_<id>_<augmented/non_augmented>_<run>.log
                if ('Bustle' in file):
                    taskId = file.split('_')[-3].split('.')[0]
                    run = file.split('_')[-1].split('.')[0]
                if ('bee' in value):
                    taskId = file.split('_')[0]
                    run = file.split('_')[-1].split('.')[0]
                if ('A-BUS' in file):
                    taskId = file.split('_')[-3]
                # open the file
                with open(value + sub_dir + file, 'r') as f:
                    # print('File:', file)
                    # read the file
                    lines = f.readlines()
                    # for each line
                    is_solution = False
                    for line in lines:
                        # if the line contains the word 'error'
                        if 'Result: Success' in line:
                            is_solution = True
                            break
                    if is_solution:
                        count = 0
                        program = ''
                        program_size = 0
                        size_total = 0
                        cur_size = 0
                        for line in lines:
                            if ('partial program added to the DSL: ' in line) or ('Program: ' in line) or ('Augmented search did not find a solution. Best programs found: ' in line):
                                count += 1
                            # if ('Number of Iterations: ' in line):
                            #     count = int(line.split('Number of Iterations: ')[1].strip())
                            if ('Program: ' in line):
                                program = line.split('Program: ')[1].strip()
                            if ('Program size: ' in line):
                                program_size = float(line.split('Program size: ')[1].strip())
                            # extract the size from the line '[Task: 35] Size: 12 Evaluations: 4994471' 
                            if ('Size: ' in line):
                                cur_size = max(cur_size, int(line.split('Size: ')[1].split(' Evaluations:')[0].strip()))
                            else:
                                size_total += cur_size
                                cur_size = 0
                        
                        if 'A-BUS' in file or 'BUS' in file:
                            if key not in result_dict:
                                result_dict[key] = []
                            result_dict[key].append({"Iteration":count, "Program": program, "Size": (program_size if 'bee' in value else size_total)})
                        if 'bee' in value:
                            if key not in result_dict:
                                result_dict[key] = {}
                            if run not in result_dict[key]:
                                result_dict[key][run] = []
                            result_dict[key][run].append({"Iteration":count, "Program": program, "Size": (program_size if 'bee' in value else size_total)})
                        if 'Bustle' in file:
                            if key not in result_dict:
                                result_dict[key] = {}
                            if run not in result_dict[key]:
                                result_dict[key][run] = []
                            result_dict[key][run].append({"Iteration":count, "Program": program, "Size": (program_size if 'bee' in value else size_total)})

    return result_dict

# %%
# directory of the logs of A-BUS
dirs = {38:'../../logs/bus_38_Jan23_2024/', 89:'../../logs/bus_89_Jan23_2024/'}
result_bus = count_iterations(dirs, 'augmented/')#, 'non_augmented/')
import json
print(json.dumps(result_bus, indent=4))

# save the json to a file
with open('A-BUS.json', 'w') as f:
    json.dump(result_bus, f)
# Out:
# {
#     "38": [
#         {
#             "Iteration": 1,
#             "Program": "arg_0.Length().IntToStr()",
#             "Size": 2
#         },
#         {
#             "Iteration": 2,
#             "Program": "(ifEqual(\"100%\",arg_0) then \"Completed\" else (ifEqual(\"0%\",arg_0[ length-2:]) then \"Not Yet Started\" else \"In Progress\"))",
#             "Size": 14
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_1[:arg_1.IndexOf(\" \")]",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "(arg_0.Length() - arg_0.replace(\"/\", \"\").Length()).IntToStr()",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.replace(\"<COMPANY>\", arg_1)",
#             "Size": 3
#         },
#         {
#             "Iteration": 2,
#             "Program": "concat(arg_0[:-4][ length-2:], concat(arg_0[:2], concat(\"/\", arg_0)[:3] + \"/\" + concat(\"/\", arg_0)[3+2:]).Substr(2:2+15))",
#             "Size": 20
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(\"+\", arg_0).replace(concat(\"+\", \"-\"), \"-\")",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(arg_0[:15], \"...\").replace(concat(arg_0, \"...\"), arg_0)",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "(ifEqual(arg_0,arg_1) then \"yes\" else \"no\")",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip()",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.title()[:1] + arg_0.lower().Substr(1:1+15) + arg_0.title()[1+15:]",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.replace(\"-\", \"/\")[ length-(1 + 4):]",
#             "Size": 7
#         },
#         {
#             "Iteration": 2,
#             "Program": "concat(\"Ms. \", arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip()).replace(arg_1.replace(\"male\", \"Ms. \"), \"Mr. \")",
#             "Size": 15
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.replace(\"com\", \"org\",1)",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0[:(0 - arg_1.Length())]",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.lower().strip()",
#             "Size": 2
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(arg_0[:-3], (ifEqual(\"morning\",arg_1) then \" AM\" else \" PM\"))",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.replace(\"-\", \"/\")",
#             "Size": 3
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0[:1] + \"\" + arg_0[1+arg_0.IndexOf(\" \"):][:2]",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "(ifEqual(arg_0.lower(),arg_1.lower()) then \"yes\" else \"no\")",
#             "Size": 7
#         },
#         {
#             "Iteration": 2,
#             "Program": "concat(concat(arg_0.replace(\"-\", \"(\"), \")\"[:(-4 + arg_0.Length())]), \")\")[:arg_0.replace(\"-\", -4.IntToStr()).Length()]",
#             "Size": 19
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.Substr(arg_0.IndexOf(\"/\",(4 + 4)):arg_0.IndexOf(\"/\",(4 + 4))+15)",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.Substr(arg_1.Length():arg_1.Length()+15)",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.replace(arg_0.replace(\".\", \"\"), concat(arg_0, \".0\"))",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(\"Mr. \", arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip())",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.upper()[:1] + \"\" + arg_0.upper()[1+arg_0.IndexOf(\" \"):][:2]",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "(ifEqual(\"NONE\",arg_0) then arg_1 else arg_0)",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.lower().replace(arg_0[:15], arg_0.upper())",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "(ifarg_1.Length() > arg_0.Length() then arg_1 else arg_0)",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(\"0\"*4, arg_0)[ length-(1 + 4):]",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(arg_0.title()[:-4], arg_0.upper()[ length-4:])",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "(ifEqual(arg_0,arg_0.lower()) then \"true\" else \"false\")",
#             "Size": 6
#         }
#     ],
#     "89": [
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(_arg_0.lower(), _arg_1)",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(_arg_0[:1], concat(_arg_1, concat(\"_\", _arg_2)))",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:_arg_0.IndexOf(\"Inc\")].strip()",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(name[:1] + \".\" + name[1+name.IndexOf(\" \"):][:(1 + 2)], \".\")",
#             "Size": 12
#         },
#         {
#             "Iteration": 1,
#             "Program": "name.Substr(1:1+name.IndexOf(\" \")).strip()",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\" \", \" \"*_arg_0.Length())[ length-_arg_0.Length():].strip()",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr((-1 + _arg_0.IndexOf(\".\")):(-1 + _arg_0.IndexOf(\".\"))+(1 + (1 + 1)))",
#             "Size": 11
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(firstname, concat(\" \", concat(lastname[:1], \".\")))",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[ length-3:]",
#             "Size": 2
#         },
#         {
#             "Iteration": 1,
#             "Program": "name.replace(\" \", \"-\").replace(\"-\", \".\").Substr(1:1+name.Length())",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:_arg_0.IndexOf(\" \")]",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:concat(_arg_0, \"|\").IndexOf(\"|\")]",
#             "Size": 6
#         },
#         {
#             "Iteration": 2,
#             "Program": "_arg_0.replace(\"2\", \"bananas\").replace(\"3\", \"strawberries\").replace(\",\", \"\").replace(\"1\", \"apple\").replace(\"4\", \"oranges\")",
#             "Size": 16
#         },
#         {
#             "Iteration": 4,
#             "Program": "concat(\" \", _arg_0.replace(0.IntToStr(), \"\")[ length-(3 + 9):]).replace(concat(\" \", 1.IntToStr()), \"\")[:concat(\" \", _arg_0.replace(0.IntToStr(), \"\")[ length-(3 + 9):]).replace(concat(\" \", _arg_0.replace(0.IntToStr(), \"\")[ length-(3 + 9):]).strip().IndexOf(\" \").IntToStr(), \"\").Length()]",
#             "Size": 22
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"/\", \" \"*_arg_0.Length())[ length-_arg_0.Length():].strip()",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(firstname[:1], concat(\".\", concat(\" \", lastname)))",
#             "Size": 8
#         },
#         {
#             "Iteration": 2,
#             "Program": "_arg_0.Substr(_arg_0.IndexOf(_arg_0.Substr((_arg_0.IndexOf(\"_\") - 4):(_arg_0.IndexOf(\"_\") - 4)+_arg_0.IndexOf(\"_\"))):_arg_0.IndexOf(_arg_0.Substr((_arg_0.IndexOf(\"_\") - 4):(_arg_0.IndexOf(\"_\") - 4)+_arg_0.IndexOf(\"_\")))+(2 + _arg_0.Substr((_arg_0.IndexOf(\"_\") - 4):(_arg_0.IndexOf(\"_\") - 4)+_arg_0.IndexOf(\"_\")).Length()))",
#             "Size": 19
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"-\", \"\")",
#             "Size": 3
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(_arg_0.replace(_arg_2.strip(), \"\"), _arg_1)",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(_arg_0, concat(\",\", _arg_0[:_arg_0.IndexOf(\",\")]))[ length-_arg_0.Length():]",
#             "Size": 11
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"<\", \" \").replace(\",\", \" \")[:-1]",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:_arg_0.replace(\" \", _arg_0).IndexOf(_arg_0)]",
#             "Size": 7
#         },
#         {
#             "Iteration": 2,
#             "Program": "_arg_0.replace(\"-\", \"\").replace(\".\", \"\").replace(concat(\">\", \" \"), \"\").replace(\"<\", \"\")",
#             "Size": 15
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"/\", \" \"*_arg_0.Length())[ length-_arg_0.Length():].strip()",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(_arg_0, concat(\" \", _arg_1))",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr(_arg_0.replace(\" \", -1.IntToStr(),1).IndexOf(\" \"):_arg_0.replace(\" \", -1.IntToStr(),1).IndexOf(\" \")+4)",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[ length-(2 + 5):][:3]",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "name.replace(\"-\", \".\")",
#             "Size": 3
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_1[:_arg_1.IndexOf(\"_\")]",
#             "Size": 4
#         },
#         {
#             "Iteration": 4,
#             "Program": "concat(5.IntToStr(), _arg_0.replace(_arg_0.replace(1.IntToStr(), \"\"), _arg_0.Substr(_arg_0.IndexOf(0.IntToStr()):_arg_0.IndexOf(0.IntToStr())+_arg_0.IndexOf(\" \")).strip()))[ length-concat(_arg_0[:1], _arg_0.Substr(_arg_0.IndexOf(0.IntToStr()):_arg_0.IndexOf(0.IntToStr())+_arg_0.IndexOf(\" \")).strip())[ length-6:].Length():]",
#             "Size": 25
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[ length-_arg_0.IndexOf(\".\"):].replace(\".\", \"\")",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(firstname, concat(\" \", lastname))",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\" \", \"\")[:_arg_0.IndexOf(\" \")] + \" \" + _arg_0.replace(\" \", \"\")[_arg_0.IndexOf(\" \")+0:]",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr(concat(-1.IntToStr(), _arg_0).IndexOf(\"=\"):concat(-1.IntToStr(), _arg_0).IndexOf(\"=\")+_arg_0.Length())",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(_arg_1.strip(), \"\").strip()",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"BRD\", \"Branding\").replace(\"DRS\", \"Direct Response\").replace(\"LDS\", \"Leads\")",
#             "Size": 9
#         },
#         {
#             "Iteration": 11,
#             "Program": "concat(col1, concat(\",\", concat(\" \", col2.replace(\"CA\", \"USA\")))).replace(\"MD\", concat(\"MD\", concat(\" \", \"USA\"))).replace(col2.replace(\"CA\", \" \").strip(), col2).replace(\"MD\", concat(\"MD\", \",\")).replace(concat(col1, concat(\",\", concat(\" \", col2.replace(\"CA\", \"USA\")))).replace(\"MD\", concat(\"MD\", concat(\" \", \"USA\"))).replace(col2.replace(\"CA\", \" \").strip(), col2), concat(col1, concat(\",\", concat(\" \", col2.replace(\"CA\", \"USA\")))).replace(\"MD\", concat(\"MD\", concat(\" \", \"USA\"))).replace(col2.replace(\"CA\", \" \").strip(), col2).replace(\"CA\", concat(\"CA\", \",\")))",
#             "Size": 37
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(_arg_1.strip(), \"\")",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"<\", \"\").replace(\">\", \"\")",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(_arg_0, concat(\"/n\", concat(_arg_1, concat(\"/n\", _arg_2))))",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:(-1 - concat(\"in\", \"in\").Length())].strip()",
#             "Size": 8
#         },
#         {
#             "Iteration": 4,
#             "Program": "_arg_0.Substr(_arg_0.IndexOf(_arg_0.Substr(_arg_0.IndexOf(\" \"):_arg_0.IndexOf(\" \")+_arg_0.Length())[:(0 - _arg_0.IndexOf(\" \"))].strip()):_arg_0.IndexOf(_arg_0.Substr(_arg_0.IndexOf(\" \"):_arg_0.IndexOf(\" \")+_arg_0.Length())[:(0 - _arg_0.IndexOf(\" \"))].strip())+_arg_0.Substr(_arg_0.IndexOf(\" \"):_arg_0.IndexOf(\" \")+_arg_0.Length())[:(0 - _arg_0.IndexOf(\" \"))].strip().replace(\" \", -1.IntToStr()).Length())[:concat(_arg_0.Substr(_arg_0.IndexOf(\" \"):_arg_0.IndexOf(\" \")+_arg_0.Length())[:(0 - _arg_0.IndexOf(\" \"))].strip(), -1.IntToStr()[:_arg_0.Substr(_arg_0.IndexOf(\" \"):_arg_0.IndexOf(\" \")+_arg_0.Length())[:(0 - _arg_0.IndexOf(\" \"))].strip().IndexOf(_arg_0.Substr(_arg_0.IndexOf(\" \"):_arg_0.IndexOf(\" \")+_arg_0.Length())[:(0 - _arg_0.IndexOf(\" \"))].strip()[ length-1:])])[:-1].Length()]",
#             "Size": 29
#         },
#         {
#             "Iteration": 2,
#             "Program": "_arg_0[ length-_arg_0.IndexOf(2.IntToStr()):].strip()[:(-1 - 5)][:concat(_arg_0[ length-_arg_0.IndexOf(2.IntToStr()):].strip()[:(-1 - 5)], \" \").IndexOf(\" \")]",
#             "Size": 17
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(col1, concat(\",\", concat(\" \", col2)))",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:_arg_0.IndexOf(\"-\")].strip()",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:_arg_0.IndexOf(\" \",concat(\"ssp.\", \"ssp.\").Length())]",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"-\", \"\")",
#             "Size": 3
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(lastname, concat(\",\", concat(\" \", concat(firstname[:1], \".\"))))",
#             "Size": 10
#         },
#         {
#             "Iteration": 2,
#             "Program": "_arg_0.Substr(_arg_0.IndexOf(\"_\"):_arg_0.IndexOf(\"_\")+(1 + _arg_0.Substr(_arg_0.IndexOf(\"_\"):_arg_0.IndexOf(\"_\")+(_arg_0.IndexOf(\"_\") - 2)).strip().Length())).strip()",
#             "Size": 21
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[:(0 - 3)]",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"that\", (ifEqual(\"that\",_arg_0) then \"that\" else \"\"))",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[ length-_arg_0.IndexOf(\" \"):].strip()",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:(-1 + _arg_0.IndexOf(\"1\"))]",
#             "Size": 6
#         },
#         {
#             "Iteration": 7,
#             "Program": "concat(col2.replace(concat(\" \", \"New York\"), concat(\" \", \"NY\")).replace(\"USA\", \" \").strip(), concat(\" \", \"USA\")).replace(\"CA\", concat(\"CA\", \",\")).replace(concat(col2.replace(concat(\" \", \"New York\"), concat(\" \", \"NY\")).replace(\"USA\", \" \").strip(), concat(\" \", \"USA\")), concat(col2.replace(concat(\" \", \"New York\"), concat(\" \", \"NY\")).replace(\"USA\", \" \").strip(), concat(\" \", \"USA\")).replace(\"MD\", concat(\"MD\", \",\")))",
#             "Size": 29
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr(_arg_0.IndexOf(\" \"):_arg_0.IndexOf(\" \")+_arg_0.Length()).strip()",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(\"Dr.\", concat(\" \", name[:name.IndexOf(\" \")]))",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr(concat(-1.IntToStr(), _arg_0).IndexOf(\"_\"):concat(-1.IntToStr(), _arg_0).IndexOf(\"_\")+_arg_0.Length())",
#             "Size": 9
#         },
#         {
#             "Iteration": 2,
#             "Program": "concat(concat(_arg_0, concat(\" \", _arg_1)).strip(), concat(\",\", concat(\" \", _arg_2)))[:_arg_0.Length()] + \",\"[:_arg_1.Length()] + concat(concat(_arg_0, concat(\" \", _arg_1)).strip(), concat(\",\", concat(\" \", _arg_2)))[_arg_0.Length()+0:]",
#             "Size": 20
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[:name.IndexOf(\"-\")][ length-3:]",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:(1 + 1)] + \"\" + _arg_0[(1 + 1)+(1 + (1 + 1)):]",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "(ifEqual(_arg_0,_arg_1) then _arg_0 else _arg_2)",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[ length-(2 + (4 + 4)):]",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "name.Substr(4:4+3)",
#             "Size": 3
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[:3]",
#             "Size": 2
#         },
#         {
#             "Iteration": 4,
#             "Program": "concat(_arg_0[:_arg_0.replace(\"/\", \" \",3).IndexOf(\" \")], \"/\").replace(concat(concat(_arg_0[:_arg_0.replace(\"/\", \" \",3).IndexOf(\" \")], \"/\")[:-1.IntToStr()*3*3.Length()], \"/\"), concat(_arg_0[:_arg_0.replace(\"/\", \" \",3).IndexOf(\" \")], \"/\")[:(_arg_0.IndexOf(_arg_0[ length-1:]) - 3)])",
#             "Size": 28
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:_arg_0.IndexOf(\".\")]",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr(concat(-1.IntToStr(), _arg_0).IndexOf(\"/\"):concat(-1.IntToStr(), _arg_0).IndexOf(\"/\")+_arg_0.Length())",
#             "Size": 9
#         },
#         {
#             "Iteration": 2,
#             "Program": "concat(col2.replace(\"USA\", \" \").strip(), concat(\" \", \"USA\")).replace(col2.replace(\"USA\", \" \"), concat(col2, \",\"))",
#             "Size": 17
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"=\", \" \"*_arg_0.Length())[ length-_arg_0.Length():].strip()",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:1] + \" \" + _arg_0[1+_arg_0.IndexOf(\" \"):]",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\" \", \"-\")",
#             "Size": 3
#         },
#         {
#             "Iteration": 2,
#             "Program": "_arg_0.replace(\"/\", _arg_0[:_arg_0.IndexOf(\"/\")])[:1] + \"\" + _arg_0.replace(\"/\", _arg_0[:_arg_0.IndexOf(\"/\")])[1+_arg_0.Length():].replace(_arg_0.replace(\"/\", _arg_0[:_arg_0.IndexOf(\"/\")])[:1] + \"\" + _arg_0.replace(\"/\", _arg_0[:_arg_0.IndexOf(\"/\")])[1+_arg_0.Length():].lower(), \"\")",
#             "Size": 17
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:-1][ length-(1 + (1 + 1)):]",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr(_arg_0.replace(\" \", _arg_0).IndexOf(\"9\"):_arg_0.replace(\" \", _arg_0).IndexOf(\"9\")+_arg_0.Length())",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[ length-concat(-1.IntToStr(), -1.IntToStr()).Length():]",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:concat(_arg_0, \" \").IndexOf(\" \",(1 + \"Company\".Length()))]",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"/n\", \" \"*_arg_0.Length())[ length-_arg_0.Length():].strip()",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(_arg_1[:1], concat(_arg_0, \"_acme.com\"))",
#             "Size": 6
#         },
#         {
#             "Iteration": 2,
#             "Program": "_arg_0[ length-\"mac\".Length():].replace(\"/\", \"microsoft\")[ length-\"microsoft\".Length():].replace(\"windows\"[ length-\"mac\".Length():], \"windows\")",
#             "Size": 16
#         },
#         {
#             "Iteration": 1,
#             "Program": "name.Substr(name.IndexOf(\" \"):name.IndexOf(\" \")+name.Length()).strip()",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(lastname, concat(\" \", firstname))",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[ length-3:]",
#             "Size": 2
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(\"(\", name[:3] + concat(\")\", \" \") + name[3+1:])",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[:name.IndexOf(\" \")]",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"US\", \"\").replace(\"CAN\", \"\").strip()",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_1.Substr((1 + _arg_1.IndexOf(\"_\")):(1 + _arg_1.IndexOf(\"_\"))+_arg_1.Length())",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(concat(\"<\", concat(\"b\", \">\")), \"\")",
#             "Size": 7
#         }
#     ]
# }

# %%
# directory of the logs of BUS
dirs = {38:'../../logs/bus_38_Jan10_2024/', 89:'../../logs/bus_89_Jan10_2024/'}
result_bus = count_iterations(dirs, 'non_augmented/')
import json
print(json.dumps(result_bus, indent=4))

# save the json to a file
with open('BUS.json', 'w') as f:
    json.dump(result_bus, f)
# Out:
# {
#     "38": [
#         {
#             "Iteration": 1,
#             "Program": "arg_0.replace(\"-\", \"/\")[ length-(1 + 4):]",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(arg_0[:15], \"...\").replace(concat(arg_0, \"...\"), arg_0)",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0[:(0 - arg_1.Length())]",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(arg_0[:-4][ length-2:], concat(\"/\", arg_0)[:3] + \"/\" + concat(\"/\", arg_0)[3+2:])",
#             "Size": 12
#         },
#         {
#             "Iteration": 1,
#             "Program": "(ifEqual(\"NONE\",arg_0) then arg_1 else arg_0)",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.Substr(arg_0.IndexOf(\"/\",(4 + 4)):arg_0.IndexOf(\"/\",(4 + 4))+15)",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "(ifarg_1.Length() > arg_0.Length() then arg_1 else arg_0)",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "(ifEqual(arg_0.lower(),arg_1.lower()) then \"yes\" else \"no\")",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "(ifEqual(arg_0,arg_0.lower()) then \"true\" else \"false\")",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.lower().replace(arg_0[:15], arg_0.upper())",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.replace(\"-\", \"/\")",
#             "Size": 3
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0[:1] + \"\" + arg_0[1+arg_0.IndexOf(\" \"):][:2]",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.Length().IntToStr()",
#             "Size": 2
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip()",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_1[:arg_1.IndexOf(\" \")]",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.replace(\"com\", \"org\",1)",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "(ifEqual(arg_0,arg_1) then \"yes\" else \"no\")",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.Length() > arg_0.replace(arg_1.strip(), \"\").Length()",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(\"Mr. \", arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip())",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(arg_0.replace(\"-\", \"(\"), \")\").replace(concat(arg_0, \")\"), arg_0)",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.lower().strip()",
#             "Size": 2
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(arg_0.title()[:-4], arg_0.upper()[ length-4:])",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "(arg_0.Length() - arg_0.replace(\"/\", \"\").Length()).IntToStr()",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(\"+\", arg_0).replace(concat(\"+\", \"-\"), \"-\")",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.replace(\"<COMPANY>\", arg_1)",
#             "Size": 3
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.title()[:1] + arg_0.lower().Substr(1:1+15) + arg_0.title()[1+15:]",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.Length() > concat(arg_0.lower(), arg_1).IndexOf(arg_1.lower())",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(\"0\"*4, arg_0)[ length-(1 + 4):]",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(arg_0[:-3], (ifEqual(\"morning\",arg_1) then \" AM\" else \" PM\"))",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.upper()[:1] + \"\" + arg_0.upper()[1+arg_0.IndexOf(\" \"):][:2]",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.replace(arg_0.replace(\".\", \"\"), concat(arg_0, \".0\"))",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "arg_0.Substr(arg_1.Length():arg_1.Length()+15)",
#             "Size": 4
#         }
#     ],
#     "89": [
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr((-1 + _arg_0.IndexOf(\".\")):(-1 + _arg_0.IndexOf(\".\"))+(1 + (1 + 1)))",
#             "Size": 11
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[:(0 - 3)]",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"/\", \" \"*_arg_0.Length())[ length-_arg_0.Length():].strip()",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "name.Substr(1:1+name.IndexOf(\" \")).strip()",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:-1][ length-(1 + (1 + 1)):]",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\" \", \"\")[:_arg_0.IndexOf(\" \")] + \" \" + _arg_0.replace(\" \", \"\")[_arg_0.IndexOf(\" \")+0:]",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(_arg_0, concat(\",\", _arg_0[:_arg_0.IndexOf(\",\")]))[ length-_arg_0.Length():]",
#             "Size": 11
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\" \", \" \"*_arg_0.Length())[ length-_arg_0.Length():].strip()",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"/n\", \" \"*_arg_0.Length())[ length-_arg_0.Length():].strip()",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:1] + \" \" + _arg_0[1+_arg_0.IndexOf(\" \"):]",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"=\", \" \"*_arg_0.Length())[ length-_arg_0.Length():].strip()",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(col1, concat(\",\", concat(\" \", col2)))",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[ length-3:]",
#             "Size": 2
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(_arg_0[:1], concat(_arg_1, concat(\"_\", _arg_2)))",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[:3]",
#             "Size": 2
#         },
#         {
#             "Iteration": 1,
#             "Program": "name.Substr(name.IndexOf(\" \"):name.IndexOf(\" \")+name.Length()).strip()",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:_arg_0.IndexOf(\"-\")].strip()",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:_arg_0.IndexOf(\".\")]",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(_arg_0, concat(\"/n\", concat(_arg_1, concat(\"/n\", _arg_2))))",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[:name.IndexOf(\"-\")][ length-3:]",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[ length-(2 + (4 + 4)):]",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:_arg_0.replace(\" \", _arg_0).IndexOf(_arg_0)]",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[ length-_arg_0.IndexOf(\" \"):].strip()",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"US\", \"\").replace(\"CAN\", \"\").strip()",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[ length-concat(-1.IntToStr(), -1.IntToStr()).Length():]",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:(1 + 1)] + \"\" + _arg_0[(1 + 1)+(1 + (1 + 1)):]",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(concat(\"<\", concat(\"b\", \">\")), \"\")",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"-\", \"\")",
#             "Size": 3
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"-\", \"\")",
#             "Size": 3
#         },
#         {
#             "Iteration": 1,
#             "Program": "name.replace(\" \", \"-\").replace(\"-\", \".\").Substr(1:1+name.Length())",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(\"Dr.\", concat(\" \", name[:name.IndexOf(\" \")]))",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:concat(_arg_0, \"|\").IndexOf(\"|\")]",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(_arg_0, concat(\" \", _arg_1))",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(_arg_1.strip(), \"\").strip()",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"BRD\", \"Branding\").replace(\"DRS\", \"Direct Response\").replace(\"LDS\", \"Leads\")",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(name[:1] + \".\" + name[1+name.IndexOf(\" \"):][:(1 + 2)], \".\")",
#             "Size": 12
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[ length-(2 + 5):][:3]",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(_arg_1[:1], concat(_arg_0, \"_acme.com\"))",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:_arg_0.IndexOf(\" \",concat(\"ssp.\", \"ssp.\").Length())]",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(_arg_0.replace(_arg_2.strip(), \"\"), _arg_1)",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(lastname, concat(\",\", concat(\" \", concat(firstname[:1], \".\"))))",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[ length-_arg_0.IndexOf(\".\"):].replace(\".\", \"\")",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:concat(_arg_0, \" \").IndexOf(\" \",(1 + \"Company\".Length()))]",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "(ifEqual(_arg_0,_arg_1) then _arg_0 else _arg_2)",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr(concat(-1.IntToStr(), _arg_0).IndexOf(\"=\"):concat(-1.IntToStr(), _arg_0).IndexOf(\"=\")+_arg_0.Length())",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr(_arg_0.replace(\" \", _arg_0).IndexOf(\"9\"):_arg_0.replace(\" \", _arg_0).IndexOf(\"9\")+_arg_0.Length())",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr((_arg_0.IndexOf(\"_\") - 4):(_arg_0.IndexOf(\"_\") - 4)+(2 + _arg_0.IndexOf(\"_\")))",
#             "Size": 11
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:(-1 + _arg_0.IndexOf(\"1\"))]",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"<\", \"\").replace(\">\", \"\")",
#             "Size": 6
#         },
#         {
#             "Iteration": 1,
#             "Program": "name.replace(\"-\", \".\")",
#             "Size": 3
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:_arg_0.IndexOf(\"Inc\")].strip()",
#             "Size": 5
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[:name.IndexOf(\" \")]",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr(_arg_0.replace(\" \", -1.IntToStr(),1).IndexOf(\" \"):_arg_0.replace(\" \", -1.IntToStr(),1).IndexOf(\" \")+4)",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr(_arg_0.IndexOf(\" \"):_arg_0.IndexOf(\" \")+_arg_0.Length()).strip()",
#             "Size": 7
#         },
#         {
#             "Iteration": 1,
#             "Program": "name[ length-3:]",
#             "Size": 2
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(_arg_1.strip(), \"\")",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"<\", \" \").replace(\",\", \" \")[:-1]",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr(_arg_0.IndexOf(\"_\"):_arg_0.IndexOf(\"_\")+_arg_0.replace(_arg_0[:1], \"\").IndexOf(\"_\")).strip()",
#             "Size": 13
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(firstname, concat(\" \", lastname))",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_1.Substr((1 + _arg_1.IndexOf(\"_\")):(1 + _arg_1.IndexOf(\"_\"))+_arg_1.Length())",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(firstname[:1], concat(\".\", concat(\" \", lastname)))",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"that\", (ifEqual(\"that\",_arg_0) then \"that\" else \"\"))",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:(-1 - concat(\"in\", \"in\").Length())].strip()",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr(concat(-1.IntToStr(), _arg_0).IndexOf(\"/\"):concat(-1.IntToStr(), _arg_0).IndexOf(\"/\")+_arg_0.Length())",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(firstname, concat(\" \", concat(lastname[:1], \".\")))",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(lastname, concat(\" \", firstname))",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_1[:_arg_1.IndexOf(\"_\")]",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\" \", \"-\")",
#             "Size": 3
#         },
#         {
#             "Iteration": 1,
#             "Program": "name.Substr(4:4+3)",
#             "Size": 3
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(_arg_0.lower(), _arg_1)",
#             "Size": 4
#         },
#         {
#             "Iteration": 1,
#             "Program": "concat(\"(\", name[:3] + concat(\")\", \" \") + name[3+1:])",
#             "Size": 8
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.replace(\"/\", \" \"*_arg_0.Length())[ length-_arg_0.Length():].strip()",
#             "Size": 10
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0.Substr(concat(-1.IntToStr(), _arg_0).IndexOf(\"_\"):concat(-1.IntToStr(), _arg_0).IndexOf(\"_\")+_arg_0.Length())",
#             "Size": 9
#         },
#         {
#             "Iteration": 1,
#             "Program": "_arg_0[:_arg_0.IndexOf(\" \")]",
#             "Size": 4
#         }
#     ]
# }

# %%
# directory of the logs of Bustle
dirs = {38:'../../logs/bustle_38/', 89:'../../logs/bustle_89/'}
result_bustle = count_iterations(dirs, 'filtered/')#, 'non_augmented/')
print(json.dumps(result_bustle, indent=4))

# save the json to a file
with open('A-Bustle.json', 'w') as f:
    json.dump(result_bustle, f)
# Out:
# {
#     "38": {
#         "3": [
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.upper()[:1], arg_0.lower().Substr(1:1+arg_0.Length()))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\")[ length-(1 + 4):]",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"Mr. \", arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip())",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:(arg_0.Length() - arg_1.Length())]",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().replace(arg_0[:15], arg_0.upper())",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat(\"Ms. \", arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip()).replace(\"Ms. \", (ifEqual(\"male\",arg_1) then \"Mr. \" else \"Ms. \"))",
#                 "Size": 27
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.title()[:-4], arg_0.upper()[ length-4:])",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"<COMPANY>\", arg_1)",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:1] + \"\" + arg_0[1+arg_0.IndexOf(\" \"):][:2]",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\")",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:4] + concat(\"/\", arg_0[:2] + \"/\" + arg_0[2+15:]) + arg_0[4+0:].Substr(2:2+15)",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0[:15], (ifEqual(arg_0,arg_0[:15]) then \"\" else \"...\"))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().strip()",
#                 "Size": 2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.replace(\"-\", \"(\"), (ifEqual(arg_0,arg_0.replace(\"-\", \"\")) then \"\" else \")\"))",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_1.Length():arg_1.Length()+15)",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Length().IntToStr()",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_1[:arg_1.IndexOf(\" \")]",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat((ifEqual(arg_0,arg_0.replace(\"-\", \"\")) then \"+\" else \"\"), arg_0)",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\"/\",(4 + 4)):arg_0.IndexOf(\"/\",(4 + 4))+15)",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0[:-3], (ifEqual(\"morning\",arg_1) then \" AM\" else \" PM\"))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(arg_0.Length() - arg_0.replace(\"/\", \"\").Length()).IntToStr()",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(arg_0.replace(\".\", \"\"), concat(arg_0, \".0\"))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(\"NONE\",arg_0) then arg_1 else arg_0)",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_1) then \"yes\" else \"no\")",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"0\"*4, arg_0)[ length-(1 + 4):]",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(concat(arg_0[:1], arg_1), \"@\"), arg_2).lower(), \".com\")",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip()",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"com\", \"org\",1)",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:1] + \"\" + arg_0[1+arg_0.IndexOf(\" \"):].upper()[:2]",
#                 "Size": 14
#             }
#         ],
#         "2": [
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\")[ length-(1 + 4):]",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.upper()[:1], arg_0.lower().Substr(1:1+arg_0.Length()))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:(0 - arg_1.Length())]",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"Mr. \", arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip())",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat(\"Ms. \", arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip()).replace(\"Ms. \", (ifEqual(\"male\",arg_1) then \"Mr. \" else \"Ms. \"))",
#                 "Size": 28
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().replace(arg_0[:15], arg_0.upper())",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.title()[:-3], arg_0.upper()[ length-3:])",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(\"0%\",arg_0) then \"Not Yet Started\" else (ifEqual(\"100%\",arg_0) then \"Completed\" else \"In Progress\"))",
#                 "Size": 16
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:1] + \"\" + arg_0[1+arg_0.IndexOf(\" \"):][:2]",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"<COMPANY>\", arg_1)",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\")",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:4] + concat(\"/\", concat(arg_0[:2], \"/\")) + arg_0[4+0:].Substr(2:2+15)",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.replace(\"-\", \"(\"), (ifEqual(arg_0,arg_0.replace(\"-\", \"\")) then \"\" else \")\"))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().strip()",
#                 "Size": 2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0[:15], (ifEqual(arg_0,arg_0[:15]) then \"\" else \"...\"))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Length().IntToStr()",
#                 "Size": 2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_1.Length():arg_1.Length()+15)",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"+\", arg_0)[ length-(1 + arg_0.replace(\"-\", \"\").Length()):]",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_1[:arg_1.IndexOf(\" \")]",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0[:-3], (ifEqual(\"morning\",arg_1) then \" AM\" else \" PM\"))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\"/\",(4 + 4)):arg_0.IndexOf(\"/\",(4 + 4))+15)",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(arg_0.Length() - arg_0.replace(\"/\", \"\").Length()).IntToStr()",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 7,
#                 "Program": "(if3 > concat((ifEqual(arg_0,arg_1) then \"yes\" else (ifEqual(arg_0,(ifEqual(arg_0,arg_1) then \"yes\" else arg_0).lower()) then \"no\" else \"yes\").replace(arg_0[:1], \"\")), arg_1.replace(\" \", \"yes\")[:1] + \"\" + arg_1.replace(\" \", \"yes\")[1+15:][:-4]).Length() then \"no\" else \"yes\")",
#                 "Size": 42
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(\"NONE\",arg_0) then arg_1 else arg_0)",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(arg_0.replace(\".\", \"\"), concat(arg_0, \".0\"))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_0.lower()) then \"true\" else \"false\")",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat((ifEqual(arg_0,arg_0[ length-arg_1[:2] + \"\" + arg_1[2+3:].Length():]) then arg_1 else arg_0), arg_1.Substr((ifEqual(arg_0,arg_0[ length-arg_1[:2] + \"\" + arg_1[2+3:].Length():]) then arg_1 else arg_0).Length():(ifEqual(arg_0,arg_0[ length-arg_1[:2] + \"\" + arg_1[2+3:].Length():]) then arg_1 else arg_0).Length()+1))",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(concat(arg_0[:1], arg_1), \"@\"), arg_2).lower(), \".com\")",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"0\"*4, arg_0)[ length-(1 + 4):]",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_1) then \"yes\" else \"no\")",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:1] + \"\" + arg_0[1+arg_0.IndexOf(\" \"):].upper()[:2]",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"com\", \"org\",1)",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((1 + arg_0.IndexOf(\" \")):(1 + arg_0.IndexOf(\" \"))+15)",
#                 "Size": 7
#             }
#         ],
#         "5": [
#             {
#                 "Iteration": 1,
#                 "Program": "concat((ifEqual(\"male\",arg_1) then \"Mr. \" else \"Ms. \"), arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip())",
#                 "Size": 15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().replace(arg_0[:15], arg_0.upper())",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.title()[:-4], arg_0.upper()[ length-4:])",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.title()[:1] + arg_0.lower().Substr(1:1+15) + arg_0.title()[1+15:]",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\")[ length-(1 + 4):]",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:(0 - arg_1.Length())]",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"Mr. \", arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip())",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:4] + concat(\"/\", arg_0[:2] + \"/\" + arg_0[2+15:]) + arg_0[4+0:].Substr(2:2+15)",
#                 "Size": 16
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().strip()",
#                 "Size": 2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0[:15], (ifEqual(arg_0,arg_0[:15]) then \"\" else \"...\"))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", concat(arg_0.replace(\"-\", \"(\"), \")\"))[:(1 + arg_0.Length())]",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:1] + \"\" + arg_0[1+arg_0.IndexOf(\" \"):][:2]",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"<COMPANY>\", arg_1)",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(\"0%\",arg_0) then \"Not Yet Started\" else (ifEqual(\"100%\",arg_0) then \"Completed\" else \"In Progress\"))",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\")",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\"/\",(4 + 4)):arg_0.IndexOf(\"/\",(4 + 4))+15)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0[:-3], (ifEqual(\"morning\",arg_1) then \" AM\" else \" PM\"))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(arg_0.Length() - arg_0.replace(\"/\", \"\").Length()).IntToStr()",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 7,
#                 "Program": "(ifEqual(arg_0,(ifEqual(arg_0,arg_1) then \"yes\" else arg_0).lower()) then \"no\" else \"yes\").replace((ifEqual(arg_0,arg_1) then \" \" else arg_0[:1]), \"\").replace((ifEqual(arg_0,(ifEqual(arg_0,arg_1) then \"yes\" else arg_0).lower()) then \"no\" else \"yes\").replace((ifEqual(arg_0,arg_1) then \" \" else arg_0[:1]), \"\").replace((ifEqual(arg_0,(ifEqual(arg_0,arg_1) then \"yes\" else arg_0).lower()) then \"no\" else \"yes\"), \" \")[ length-1:], \"no\")[ length-concat((ifEqual(arg_0,(ifEqual(arg_0,arg_1) then \"yes\" else arg_0).lower()) then \"no\" else \"yes\").replace((ifEqual(arg_0,arg_1) then \" \" else arg_0[:1]), \"\"), arg_1.replace(\" \", \"yes\")[:-3].Substr(15:15+1)).Length():].replace((ifEqual(arg_0,(ifEqual(arg_0,arg_1) then \"yes\" else arg_0).lower()) then \"no\" else \"yes\").replace((ifEqual(arg_0,arg_1) then \" \" else arg_0[:1]), \"\").replace((ifEqual(arg_0,(ifEqual(arg_0,arg_1) then \"yes\" else arg_0).lower()) then \"no\" else \"yes\").replace((ifEqual(arg_0,arg_1) then \" \" else arg_0[:1]), \"\").replace((ifEqual(arg_0,(ifEqual(arg_0,arg_1) then \"yes\" else arg_0).lower()) then \"no\" else \"yes\"), \" \")[ length-1:], \"no\"), (ifEqual(arg_0,(ifEqual(arg_0,arg_1) then \"yes\" else arg_0).lower()) then \"no\" else \"yes\"))",
#                 "Size": 39
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Length().IntToStr()",
#                 "Size": 2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_1.Length():arg_1.Length()+15)",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_1[:arg_1.IndexOf(\" \")]",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"+\", arg_0)[ length-(1 + arg_0.replace(\"-\", \"\").Length()):]",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"0\"*4, arg_0)[ length-(1 + 4):]",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_1) then \"yes\" else \"no\")",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(concat(arg_0[:1], arg_1), \"@\"), arg_2).lower(), \".com\")",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip()",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:1] + \"\" + arg_0[1+arg_0.IndexOf(\" \"):].upper()[:2]",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"com\", \"org\",1)",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_0.lower()) then \"true\" else \"false\")",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(arg_0.replace(\".\", \" \"), concat(arg_0, \".0\"))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(\"NONE\",arg_0) then arg_1 else arg_0)",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_1.replace(arg_1[:arg_0.Length()] + \"\" + arg_1[arg_0.Length()+1:], arg_0)",
#                 "Size": 9
#             }
#         ],
#         "4": [
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().replace(arg_0[:15], arg_0.upper())",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "arg_0.Substr((2 + 4):(2 + 4)+(2 + arg_0.Substr(4:4+arg_0[:1] + \"\" + arg_0[1+4:].IndexOf(\"/\",4)).Substr(3:3+15).replace(\"/\", \"\").Length())).replace(\"/\", \"\")",
#                 "Size": 36
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.title()[:-4], arg_0.upper()[ length-4:])",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\")[ length-(1 + 4):]",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.upper()[:1], arg_0.lower().Substr(1:1+arg_0.Length()))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"Mr. \", arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip())",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:-1][:(1 - arg_1.Length())]",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:4] + concat(\"/\", concat(arg_0[:2], \"/\")) + arg_0[4+0:].Substr(2:2+15)",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", concat(arg_0.replace(\"-\", \"(\"), \")\"))[:(1 + arg_0.Length())]",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0[:15], \"...\").replace(arg_0[:15] + \"...\" + arg_0[15+0:], arg_0)",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().strip()",
#                 "Size": 2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(arg_0.replace(\"0%\", \"Not Yet Started\"), \"In Progress\").replace(\"100%\", \"Completed\").replace(\"0%\", \"Not Yet Started\")",
#                 "Size": 15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"<COMPANY>\", arg_1)",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:1] + \"\" + arg_0[1+arg_0.IndexOf(\" \"):][:2]",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\")",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0[:-3], (ifEqual(\"morning\",arg_1) then \" AM\" else \" PM\"))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\"/\",(4 + 4)):arg_0.IndexOf(\"/\",(4 + 4))+15)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(arg_0.Length() - arg_0.replace(\"/\", \"\").Length()).IntToStr()",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_1.Length():arg_1.Length()+15)",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Length().IntToStr()",
#                 "Size": 2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"+\", arg_0)[ length-(1 + arg_0.replace(\"-\", \"\").Length()):]",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_1[:arg_1.IndexOf(\" \")]",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(concat(arg_0[:1], arg_1), \"@\"), arg_2).lower(), \".com\")",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_1) then \"yes\" else \"no\")",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"0\"*4, arg_0)[ length-(1 + 4):]",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"com\", \"org\",1)",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:1] + \"\" + arg_0[1+arg_0.IndexOf(\" \"):].upper()[:2]",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip()",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(\"NONE\",arg_0) then arg_1 else arg_0)",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(arg_0.replace(\".\", \"\"), concat(arg_0, \".0\"))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_0.lower()) then \"true\" else \"false\")",
#                 "Size": 11
#             }
#         ],
#         "1": [
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"Mr. \", arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip())",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:(0 - arg_1.Length())]",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\")[ length-(1 + 4):]",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.upper()[:1], arg_0.lower().Substr(1:1+arg_0.Length()))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 7,
#                 "Program": "arg_0.Substr((2 + arg_0.IndexOf(\"//\")):(2 + arg_0.IndexOf(\"//\"))+concat(\" \", arg_0).replace(\"/\", \"\")[:1] + \"\" + concat(\" \", arg_0).replace(\"/\", \"\")[1+arg_0.IndexOf(\"//\"):].strip()[:-4].Length()).replace(\"/\", \"\").replace(concat(\" \", arg_0).replace(\"/\", \"\")[:1] + \"\" + concat(\" \", arg_0).replace(\"/\", \"\")[1+arg_0.IndexOf(\"//\"):].strip()[:-4], arg_0.Substr(arg_0.IndexOf(arg_0.Substr((2 + arg_0.IndexOf(\"//\")):(2 + arg_0.IndexOf(\"//\"))+concat(\" \", arg_0).replace(\"/\", \"\")[:1] + \"\" + concat(\" \", arg_0).replace(\"/\", \"\")[1+arg_0.IndexOf(\"//\"):].strip()[:-4].Length()).replace(\"/\", \"\")):arg_0.IndexOf(arg_0.Substr((2 + arg_0.IndexOf(\"//\")):(2 + arg_0.IndexOf(\"//\"))+concat(\" \", arg_0).replace(\"/\", \"\")[:1] + \"\" + concat(\" \", arg_0).replace(\"/\", \"\")[1+arg_0.IndexOf(\"//\"):].strip()[:-4].Length()).replace(\"/\", \"\"))+(4 + arg_0.Substr((2 + arg_0.IndexOf(\"//\")):(2 + arg_0.IndexOf(\"//\"))+concat(\" \", arg_0).replace(\"/\", \"\")[:1] + \"\" + concat(\" \", arg_0).replace(\"/\", \"\")[1+arg_0.IndexOf(\"//\"):].strip()[:-4].Length()).replace(\"/\", \"\")[:15].Length())))[:concat(arg_0.Substr((2 + arg_0.IndexOf(\"//\")):(2 + arg_0.IndexOf(\"//\"))+concat(\" \", arg_0).replace(\"/\", \"\")[:1] + \"\" + concat(\" \", arg_0).replace(\"/\", \"\")[1+arg_0.IndexOf(\"//\"):].strip()[:-4].Length()).replace(\"/\", \"\").replace(concat(\" \", arg_0).replace(\"/\", \"\")[:1] + \"\" + concat(\" \", arg_0).replace(\"/\", \"\")[1+arg_0.IndexOf(\"//\"):].strip()[:-4], arg_0.Substr(arg_0.IndexOf(arg_0.Substr((2 + arg_0.IndexOf(\"//\")):(2 + arg_0.IndexOf(\"//\"))+concat(\" \", arg_0).replace(\"/\", \"\")[:1] + \"\" + concat(\" \", arg_0).replace(\"/\", \"\")[1+arg_0.IndexOf(\"//\"):].strip()[:-4].Length()).replace(\"/\", \"\")):arg_0.IndexOf(arg_0.Substr((2 + arg_0.IndexOf(\"//\")):(2 + arg_0.IndexOf(\"//\"))+concat(\" \", arg_0).replace(\"/\", \"\")[:1] + \"\" + concat(\" \", arg_0).replace(\"/\", \"\")[1+arg_0.IndexOf(\"//\"):].strip()[:-4].Length()).replace(\"/\", \"\"))+(4 + arg_0.Substr((2 + arg_0.IndexOf(\"//\")):(2 + arg_0.IndexOf(\"//\"))+concat(\" \", arg_0).replace(\"/\", \"\")[:1] + \"\" + concat(\" \", arg_0).replace(\"/\", \"\")[1+arg_0.IndexOf(\"//\"):].strip()[:-4].Length()).replace(\"/\", \"\")[:15].Length()))), \"//\").IndexOf(\"/\")]",
#                 "Size": 48
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.title()[:-4], arg_0.upper()[ length-4:])",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().replace(arg_0[:15], arg_0.upper())",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat(\"Ms. \", arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip()).replace(\"Ms. \", (ifEqual(\"male\",arg_1) then \"Mr. \" else \"Ms. \"))",
#                 "Size": 22
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\")",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(\"0%\",arg_0) then \"Not Yet Started\" else (ifEqual(\"100%\",arg_0) then \"Completed\" else \"In Progress\"))",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"<COMPANY>\", arg_1)",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:1] + \"\" + arg_0[1+arg_0.IndexOf(\" \"):][:2]",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", concat(arg_0.replace(\"-\", \"(\"), \")\"))[:(1 + arg_0.Length())]",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0[:15], (ifEqual(arg_0,arg_0[:15]) then \"\" else \"...\"))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().strip()",
#                 "Size": 2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:4] + concat(\"/\", concat(arg_0[:2], \"/\")) + arg_0[4+0:].Substr(2:2+15)",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(arg_0.replace(\"-\", \" \"), concat(\"+\", arg_0))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_1[:arg_1.IndexOf(\" \")]",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_1.Length():arg_1.Length()+15)",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Length().IntToStr()",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(arg_0.Length() - arg_0.replace(\"/\", \"\").Length()).IntToStr()",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0[:-3], (ifEqual(\"morning\",arg_1) then \" AM\" else \" PM\"))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[ length-(15 - arg_0[ length-15:].IndexOf(\"/\",(2 + 4))):]",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(\"NONE\",arg_0) then arg_1 else arg_0)",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(arg_0.replace(\".\", \"\"), concat(arg_0, \".0\"))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_0.lower()) then \"true\" else \"false\")",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"com\", \"org\",1)",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0[:1] + \"\" + arg_0[1+arg_0.IndexOf(\" \"):].upper()[:2]",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\" \"):arg_0.IndexOf(\" \")+15).strip()",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(concat(arg_0[:1], arg_1), \"@\"), arg_2).lower(), \".com\")",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_1) then \"yes\" else \"no\")",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"0\"*4, arg_0)[ length-(1 + 4):]",
#                 "Size": 8
#             }
#         ]
#     },
#     "89": {
#         "4": [
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(_arg_0.replace(concat(_arg_2, _arg_0[ length-1:]), \" \"), _arg_1)",
#                 "Size": 15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"<\", \" \").replace(\",\", \" \")[:-1]",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"-\", \"\")",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(_arg_0[:_arg_0.IndexOf(0.IntToStr())], \"\")",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(firstname, concat(\" \", concat(lastname[:1], \".\")))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name[:name.IndexOf(\"-\")][ length-3:]",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"BRD\", \"Branding\").replace(\"DRS\", \"Direct Response\").replace(\"LDS\", \"Leads\")",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(firstname[:1], concat(\".\", concat(\" \", lastname)))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-_arg_0.IndexOf(\" \"):].strip()",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "_arg_0.Substr(_arg_0.IndexOf(_arg_0.Substr(_arg_0[:1] + \"\" + _arg_0[1+4:].IndexOf(\"_\"):_arg_0[:1] + \"\" + _arg_0[1+4:].IndexOf(\"_\")+_arg_0.replace(\" \", _arg_0).IndexOf(\" \"))):_arg_0.IndexOf(_arg_0.Substr(_arg_0[:1] + \"\" + _arg_0[1+4:].IndexOf(\"_\"):_arg_0[:1] + \"\" + _arg_0[1+4:].IndexOf(\"_\")+_arg_0.replace(\" \", _arg_0).IndexOf(\" \")))+_arg_0.IndexOf(_arg_0.Substr(_arg_0[:1] + \"\" + _arg_0[1+4:].IndexOf(\"_\"):_arg_0[:1] + \"\" + _arg_0[1+4:].IndexOf(\"_\")+_arg_0.replace(\" \", _arg_0).IndexOf(\" \"))[ length-_arg_0.IndexOf(_arg_0.Substr(_arg_0[:1] + \"\" + _arg_0[1+4:].IndexOf(\"_\"):_arg_0[:1] + \"\" + _arg_0[1+4:].IndexOf(\"_\")+_arg_0.replace(\" \", _arg_0).IndexOf(\" \"))):]))",
#                 "Size": 27
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name[:name[:5] + \" \".strip() + name[5+3:].Length()]",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:1] + \" \" + _arg_0[1+_arg_0.IndexOf(\" \"):]",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(_arg_0, concat(\",\", _arg_0[:_arg_0.IndexOf(\",\")]))[ length-_arg_0.Length():]",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(lastname, concat(\",\", concat(\" \", concat(firstname[:1], \".\"))))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"-\", \"\")",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(_arg_0.IndexOf(\"_\"):_arg_0.IndexOf(\"_\")+_arg_0.replace(_arg_0[:1], \"\").IndexOf(\"_\")).strip()",
#                 "Size": 18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"that\", (ifEqual(\"that\",_arg_0) then \"that\" else \"\"))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:(-1 + _arg_0.IndexOf(\"1\"))]",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:3] + \"\" + _arg_0[3+8:][:9][ length-3:].replace(\"%\", _arg_0)[ length-8:][:6]",
#                 "Size": 15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr(1:1+name.IndexOf(\" \")).strip()",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(_arg_0,_arg_1) then _arg_0 else _arg_2)",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:(-1 + _arg_0.IndexOf(\"-\"))]",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-(-1 + _arg_0.IndexOf(_arg_0[ length-(1 + _arg_0.IndexOf(\"/\")):])):]",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(_arg_0, concat(\"/n\", concat(_arg_1, concat(\"/n\", _arg_2))))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 7,
#                 "Program": "(ifEqual(col2,col2.replace(concat(\" \", \"New York\"), \"NY\")) then concat(col2.replace(concat(\" \", \"New York\"), \"NY\").replace(\"USA\", \" \").strip(), concat(\" \", \"USA\")).replace(col2.replace(\"USA\", \" \"), concat(col2, \",\")) else concat(col2.replace(concat(\" \", \"New York\"), \"NY\").replace(\"USA\", \" \").strip(), concat(\" \", \"USA\")).replace(\"NY\", concat(\" \", \"NY\")))",
#                 "Size": 35
#             },
#             {
#                 "Iteration": 4,
#                 "Program": "name.replace(\"-\", concat(\")\", \" \"),1)[:4] + \"(\" + name.replace(\"-\", concat(\")\", \" \"),1)[4+0:].replace(\"(\", \" \")[:(name.IndexOf(\"-\") - 3)] + \"(\" + name.replace(\"-\", concat(\")\", \" \"),1)[:4] + \"(\" + name.replace(\"-\", concat(\")\", \" \"),1)[4+0:].replace(\"(\", \" \")[(name.IndexOf(\"-\") - 3)+1:][:1] + concat(name[:(name.IndexOf(\"-\") - 3)], concat(\"(\", name.replace(\"-\", concat(\")\", \" \"),1)[:4] + \"(\" + name.replace(\"-\", concat(\")\", \" \"),1)[4+0:].Substr(5:5+name.Length()).strip())).Substr(1:1+4) + name.replace(\"-\", concat(\")\", \" \"),1)[:4] + \"(\" + name.replace(\"-\", concat(\")\", \" \"),1)[4+0:].replace(\"(\", \" \")[:(name.IndexOf(\"-\") - 3)] + \"(\" + name.replace(\"-\", concat(\")\", \" \"),1)[:4] + \"(\" + name.replace(\"-\", concat(\")\", \" \"),1)[4+0:].replace(\"(\", \" \")[(name.IndexOf(\"-\") - 3)+1:][1+4:]",
#                 "Size": 40
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\" \", _arg_0[:(-1 - (1 + (1 + (1 + (1 + 1)))))])[:1] + \"\" + concat(\" \", _arg_0[:(-1 - (1 + (1 + (1 + (1 + 1)))))])[1+_arg_0.IndexOf(\" \"):].strip()",
#                 "Size": 26
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\" \", \"\")[:_arg_0.IndexOf(\" \")] + \" \" + _arg_0.replace(\" \", \"\")[_arg_0.IndexOf(\" \")+0:]",
#                 "Size": 19
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\" \", _arg_0.replace(\"/\", _arg_0[:_arg_0.IndexOf(\"/\")]))[:1] + \"\" + concat(\" \", _arg_0.replace(\"/\", _arg_0[:_arg_0.IndexOf(\"/\")]))[1+_arg_0.Length():].strip()",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_1.Substr((1 + _arg_1.IndexOf(\"_\")):(1 + _arg_1.IndexOf(\"_\"))+(1 + _arg_0.Length()))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:_arg_0.replace(\" \", _arg_0).IndexOf(_arg_0)]",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-(-1 + _arg_0.IndexOf(_arg_0[ length-_arg_0.IndexOf(\" \",(1 + _arg_0.IndexOf(\" \"))):])):]",
#                 "Size": 18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:_arg_0.IndexOf(\".\")]",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:-1][:-1][:-1][:-1][:-1].strip()",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"<\", \"\").replace(\">\", \"\")",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-(2 + (4 + 4)):]",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "_arg_0[ length-_arg_0.replace(\" \", _arg_0[ length-concat(_arg_0[:-1], \"/n\").IndexOf(\"/n\"):][:1] + 1.IntToStr() + _arg_0[ length-concat(_arg_0[:-1], \"/n\").IndexOf(\"/n\"):][1+0:]).IndexOf(_arg_0[ length-1:]):]",
#                 "Size": 42
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-_arg_0.IndexOf(\".\"):].replace(\".\", \"\")",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:concat(_arg_0, \"|\").IndexOf(\"|\")]",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:-1][ length-(1 + (1 + 1)):]",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\" \", _arg_0)[:1] + \"\" + concat(\" \", _arg_0)[1+(1 + _arg_0.IndexOf(\"=\")):].strip()",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-(1 + (1 + (1 + 1))):]",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(firstname, concat(\" \", lastname))",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_1[:_arg_1.IndexOf(\"_\")]",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(_arg_1[:1], concat(_arg_0, \"_acme.com\"))",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.replace(\"-\", \".\")",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr((1 + name.IndexOf(\" \")):(1 + name.IndexOf(\" \"))+name.Length())",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((-1 + _arg_0.IndexOf(\".\")):(-1 + _arg_0.IndexOf(\".\"))+(1 + (1 + 1)))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(_arg_1.strip(), \"\")",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "_arg_0[ length-(1 + _arg_0[ length-_arg_0[ length-concat(\" \", _arg_0).IndexOf(\"-\"):].replace(\" \", \"=\",1).IndexOf(\" \"):].Length()):].strip()",
#                 "Size": 30
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(col1, concat(\",\", concat(\" \", col2)))",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(_arg_0.IndexOf(1.IntToStr(),(3 + _arg_0.IndexOf(\" \"))):_arg_0.IndexOf(1.IntToStr(),(3 + _arg_0.IndexOf(\" \")))+4)",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name[ length-3:]",
#                 "Size": 2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-(1 + (1 + _arg_0.IndexOf(\"/\"))):].replace(\"/\", \"\")",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name[ length-(2 + 5):][:3]",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(lastname, concat(\" \", firstname))",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-\"mac\".Length():].replace(\"/\", \"microsoft\").replace(\"windows\"[ length-\"mac\".Length():], \"windows\")[ length-\"microsoft\".Length():]",
#                 "Size": 15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"-\", \"\").replace(\" \", \"\").replace(\".\", \"\").replace(\"<\", \"\").replace(\">\", \"\")",
#                 "Size": 15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name[:name.IndexOf(\" \")]",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(_arg_0, concat(\" \", _arg_1))",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"(\", name[:3] + concat(\")\", \" \") + name[3+1:])",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:(1 + 1)] + \"\" + _arg_0[(1 + 1)+(1 + (1 + 1)):]",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(_arg_1.strip(), \"\").strip()",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\" \", \"-\")",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-(1 + concat(\"Name\", concat(\"Name\", _arg_0)).IndexOf(\" \")):].strip()",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.replace(\" \", \"-\").replace(\"-\", \".\").replace(\"+\", \" \").strip()",
#                 "Size": 15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr(4:4+3)",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(name[:1], concat(\".\", concat(name.Substr((1 + name.IndexOf(\" \")):(1 + name.IndexOf(\" \"))+1), \".\")))",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(_arg_0[:1], concat(_arg_1, concat(\"_\", _arg_2)))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"US\", \"\").replace(\"CAN\", \"\").strip()",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"1\", \"apple\").replace(\",\", \"\").replace(\"2\", \"bananas\").replace(\"3\", \"strawberries\").replace(\"4\", \"oranges\")",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(_arg_0, concat(\",\", concat(\" \", concat(_arg_1, (ifEqual(_arg_1,\"\".strip()) then _arg_2 else concat(\",\", concat(\" \", _arg_2)))))))",
#                 "Size": 19
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name[ length-3:]",
#                 "Size": 2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"Dr.\", concat(\" \", name[:name.IndexOf(\" \")]))",
# ...
#                 "Program": "_arg_0.replace(\"Inc\", \"\").replace(\"Company\", \"\").replace(\"Corporation\", \"\").replace(\"Enterprises\", \"\").strip()",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(_arg_0.lower(), _arg_1)",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "col2.replace(col2.replace(\"USA\", \" \"), concat(col2, concat(\",\", concat(\" \", \"USA\"))))",
#                 "Size": 12
#             }
#         ],
#         "2": [
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:1] + \" \" + _arg_0[1+_arg_0.IndexOf(\" \"):]",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(lastname, concat(\",\", concat(\" \", concat(firstname[:1], \".\"))))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(_arg_0, concat(\",\", _arg_0[:_arg_0.IndexOf(\",\")]))[ length-_arg_0.Length():]",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(_arg_0.IndexOf(\"_\"):_arg_0.IndexOf(\"_\")+concat(_arg_0, _arg_0)[:1] + \"\" + concat(_arg_0, _arg_0)[1+_arg_0.IndexOf(\"_\"):].IndexOf(\" \"))",
#                 "Size": 19
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"-\", \"\")",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"that\", (ifEqual(\"that\",_arg_0) then \"that\" else \"\"))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:(-1 + _arg_0.IndexOf(\"1\"))]",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-_arg_0.IndexOf(_arg_0.replace(\"/\", _arg_0)[ length-_arg_0.Length():][:(1 + 1)]):]",
#                 "Size": 18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(_arg_0,_arg_1) then _arg_0 else _arg_2)",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr(1:1+name.IndexOf(\" \")).strip()",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(if_arg_2.IndexOf(_arg_2[ length-1:]) > 1 then _arg_0 else _arg_1)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"-\", \"\")",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"<\", \" \").replace(\",\", \" \")[:-1]",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-_arg_0.IndexOf(\"<\",1):][:-1][:-1][:-1]",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name[:name.IndexOf(\"-\")][ length-3:]",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(firstname, concat(\" \", concat(lastname[:1], \".\")))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"BRD\", \"Branding\").replace(\"DRS\", \"Direct Response\").replace(\"LDS\", \"Leads\")",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-_arg_0.IndexOf(\" \"):].strip()",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(firstname[:1], concat(\".\", concat(\" \", lastname)))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name[:(0 - 3)]",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(4:4+_arg_0.IndexOf(\".\"))[ length-(2 + (4 + (4 + 4))):].strip()",
#                 "Size": 18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:(-1 - (1 + (\"in\".Length() + \"in\".Length())))]",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:_arg_0.IndexOf(\".\")]",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"<\", \"\").replace(\">\", \"\")",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-(2 + (4 + 4)):]",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-_arg_0.IndexOf(\".\"):].replace(\".\", \"\")",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"/n\", \" \"*_arg_0.Length())[ length-_arg_0.Length():].strip()",
#                 "Size": 15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:concat(_arg_0, \"|\").IndexOf(\"|\")]",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(((1 + 1) + _arg_0.IndexOf(\"=\")):((1 + 1) + _arg_0.IndexOf(\"=\"))+_arg_0.IndexOf(_arg_0[ length-1:]))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:-1][ length-(1 + (1 + 1)):]",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(firstname, concat(\" \", lastname))",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-(1 + (1 + (1 + 1))):]",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:(-1 + _arg_0.IndexOf(\"-\"))]",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(_arg_0, concat(\"/n\", concat(_arg_1, concat(\"/n\", _arg_2))))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((1 + (1 + _arg_0.IndexOf(\"/\"))):(1 + (1 + _arg_0.IndexOf(\"/\")))+_arg_0.Length())",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\" \", _arg_0[:(-1 + (-1 + (-1 + (-1 + (-1 + -1)))))])[:1] + \"\" + concat(\" \", _arg_0[:(-1 + (-1 + (-1 + (-1 + (-1 + -1)))))])[1+_arg_0.IndexOf(\" \"):].strip()",
#                 "Size": 22
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\" \", \"\")[:_arg_0.IndexOf(\" \")] + \" \" + _arg_0.replace(\" \", \"\")[_arg_0.IndexOf(\" \")+0:]",
#                 "Size": 17
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\" \", _arg_0.replace(\"/\", _arg_0[:_arg_0.IndexOf(\"/\")]))[:1] + \"\" + concat(\" \", _arg_0.replace(\"/\", _arg_0[:_arg_0.IndexOf(\"/\")]))[1+_arg_0.Length():].strip()",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:_arg_0.replace(\" \", _arg_0).IndexOf(_arg_0)]",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_1[ length-(-1 + _arg_1[:1] + \"\" + _arg_1[1+_arg_1.IndexOf(\"_\"):].Length()):]",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((1 + _arg_0.IndexOf(\" \",(1 + _arg_0.IndexOf(\" \")))):(1 + _arg_0.IndexOf(\" \",(1 + _arg_0.IndexOf(\" \"))))+_arg_0.Length())",
#                 "Size": 18
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat(\" \", _arg_0[ length-(6 + _arg_0.Substr(3:3+7).replace(_arg_0[ length-7:], \" \").Length()):].strip().replace(_arg_0[ length-(6 + _arg_0.Substr(3:3+7).replace(_arg_0[ length-7:], \" \").Length()):], _arg_0[:9]))",
#                 "Size": 21
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(lastname, concat(\" \", firstname))",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name[ length-(2 + 5):][:3]",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name[:name.IndexOf(\" \")]",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"-\", \"\").replace(\" \", \"\").replace(\".\", \"\").replace(\"<\", \"\").replace(\">\", \"\")",
#                 "Size": 15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"(\", name[:3] + concat(\")\", \" \") + name[3+1:])",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(_arg_0, concat(\" \", _arg_1))",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:(1 + 1)] + \"\" + _arg_0[(1 + 1)+(1 + (1 + 1)):]",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\" \", \"-\")",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(_arg_1.strip(), \"\").strip()",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(_arg_1[:1], concat(_arg_0, \"_acme.com\"))",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_1[:_arg_1.IndexOf(\"_\")]",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr((1 + name.IndexOf(\" \")):(1 + name.IndexOf(\" \"))+name.Length())",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.replace(\"-\", \".\")",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((-1 + _arg_0.IndexOf(\".\")):(-1 + _arg_0.IndexOf(\".\"))+(1 + (1 + 1)))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-_arg_0.replace(\"=\", _arg_0)[ length-_arg_0.IndexOf(\"=\"):].IndexOf(_arg_0[ length-(1 + _arg_0.IndexOf(\" \")):]):]",
#                 "Size": 25
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(_arg_1.strip(), \"\")",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(col1, concat(\",\", concat(\" \", col2)))",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name[ length-3:]",
#                 "Size": 2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(_arg_0.IndexOf(1.IntToStr(),(3 + _arg_0.IndexOf(\" \"))):_arg_0.IndexOf(1.IntToStr(),(3 + _arg_0.IndexOf(\" \")))+4)",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-(1 + (1 + _arg_0.IndexOf(\"/\"))):].replace(\"/\", \"\")",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name[ length-3:]",
#                 "Size": 2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(concat(_arg_0, \",\"), \" \"), _arg_1).strip()[:-1], concat(_arg_1[ length-1:], concat(\",\", concat(\" \", _arg_2))))",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:_arg_0.IndexOf(\" \")]",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"Dr.\", concat(\" \", name[:name.IndexOf(\" \")]))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:_arg_0.IndexOf(\" \",(\"ssp.\".Length() + \"ssp.\".Length()))]",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(_arg_0.lower(), _arg_1)",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"Inc\", \"\").replace(\"Company\", \"\").replace(\"Corporation\", \"\").replace(\"Enterprises\", \"\").strip()",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[:(-1 + _arg_0.IndexOf(\"Inc\"))]",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name[:3]",
#                 "Size": 2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(col1, concat(\",\", concat(\" \", concat(col2.replace(concat(\",\", concat(\" \", \"USA\")), \" \".strip()), concat(\",\", concat(\" \", \"USA\"))))))",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0[ length-(-1 + _arg_0.IndexOf(_arg_0[ length-_arg_0.IndexOf(\" \"):])):]",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr(1:1+name.Length()).replace(\"-\", \" \").replace(\" \", \".\")",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "_arg_0[ length-_arg_0[ length-(1 + (1 + (1 + _arg_0.replace(_arg_0[ length-1:], \"4\").IndexOf(\"4\")))):].replace(\"7\", _arg_0[ length-(1 + 1):]).Length():]",
#                 "Size": 33
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(name[:1], concat(\".\", concat(name.Substr((1 + name.IndexOf(\" \")):(1 + name.IndexOf(\" \"))+1), \".\")))",
#                 "Size": 21
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr(4:4+3)",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(_arg_0[:1], concat(_arg_1, concat(\"_\", _arg_2)))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "_arg_0[:(0 - concat(_arg_0[:_arg_0.IndexOf(\"/\",(2 + (3 + 3)))], \"/\").title().IndexOf(concat(concat(_arg_0[:_arg_0.IndexOf(\"/\",(2 + (3 + 3)))], \"/\"), _arg_0).Substr(_arg_0.Length():_arg_0.Length()+1)))]",
#                 "Size": 29
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"US\", \"\").replace(\"CAN\", \"\").strip()",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"1\", \"apple\").replace(\",\", \"\").replace(\"2\", \"bananas\").replace(\"3\", \"strawberries\").replace(\"4\", \"oranges\")",
#                 "Size": 20
#             }
#         ]
#     }
# }

# %%
# directory of the logs of Bee
dirs = {38:'../../logs/bee_38_Jan24_2024/', 89:'../../logs/bee_89_Jan24_2024/'}
result_bee = count_iterations(dirs, 'augmented/')#, 'non_augmented/')
print(json.dumps(result_bee, indent=4))

# save the json to a file
with open('A-Bee.json', 'w') as f:
    json.dump(result_bee, f)
# Out:
# {
#     "38": {
#         "3": [
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_1.Length(),15)",
#                 "Size": 5.42
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Length().IntToStr()",
#                 "Size": 3.57
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_1.Substr(0,arg_1.IndexOf(\" \"))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\"/\",(-3 * -3)),arg_0.Length())",
#                 "Size": 10.84
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "(ifarg_1.replace(\" \", \"yes\").Contain(\" \") then (ifarg_1.Contain(arg_0.Substr(2,-3)) then (ifconcat(concat(\"no\", \"yes\"), arg_0).lower().Contain(arg_1) then \"yes\" else \"no\") else \"yes\") else (ifarg_1.Substr(-4,3).SuffixOf(arg_1) then (ifconcat(concat(\"no\", \"yes\"), arg_0).lower().Contain(arg_1) then \"yes\" else \"no\") else \"yes\"))",
#                 "Size": 10.26
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(concat(arg_0.Substr(4,-3), \"NONE\"), arg_1)",
#                 "Size": 9.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifconcat(concat(\"true\", \"false\"), arg_0).lower().Contain(arg_0) then \"true\" else \"false\")",
#                 "Size": 12.17
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_1.replace(arg_1.replace(arg_0.Substr(0,-3), arg_1.Substr(0,-2)), arg_0)",
#                 "Size": 14.34
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_1) then \"yes\" else \"no\")",
#                 "Size": 7.26
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat(concat(concat(concat(arg_0.Substr(2,15), concat(\"0\", \"0\")), \"0\").Substr(-3,3), arg_0).Substr(-4,1), concat(concat(concat(arg_0.Substr(2,15), concat(\"0\", \"0\")), \"0\").Substr(-3,3), arg_0))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"com\", \"org\")",
#                 "Size": 4.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.CharAt(0), arg_0.CharAt((arg_0.IndexOf(\" \") + 1))).upper()",
#                 "Size": 17.49
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().replace(arg_0.lower().CharAt(0), arg_0.upper().CharAt(0))",
#                 "Size": 11.42
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((arg_0.IndexOf(\" \") + 1),arg_0.Length())",
#                 "Size": 9.09
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((1 + 4),15).replace(\"-\", \"/\")",
#                 "Size": 11.27
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(concat(arg_0.CharAt(0), arg_1), \"@\"), arg_2).lower(), \".com\")",
#                 "Size": 12.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.replace(\" \", \"Mr. \"), \" \").Substr(arg_0.IndexOf(\" \"),-1)",
#                 "Size": 19.05
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(0,(arg_1.Length() * -1))",
#                 "Size": 7.11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().replace(concat(\"\".lower(), arg_0), arg_0.upper())",
#                 "Size": 9.0
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "arg_0.replace(arg_0.Substr(0,15), (ifEqual(\"male\",arg_1) then \"Mr. \" else \"Ms. \").replace(\" \", arg_0.Substr(arg_0.IndexOf(\" \"),15)))",
#                 "Size": 11.26
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0, (ifarg_0.Contain(\".\") then \"\" else \".0\"))",
#                 "Size": 9.45
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((arg_0.IndexOf(\"//\") + 2),arg_0.IndexOf(\"/\",(-4 + -4)))",
#                 "Size": 16.58
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(if\"100%\".Contain(arg_0) then arg_0 else \"In Progress\").replace(\"100%\", \"Completed\").replace(\"0%\", \"Not Yet Started\")",
#                 "Size": 13.69
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"<COMPANY>\", arg_1).replace(\"<COMPANY>\", arg_1).replace(\"<COMPANY>\", arg_1)",
#                 "Size": 10.059999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.CharAt(0), arg_0.CharAt((arg_0.IndexOf(\" \") + 1)))",
#                 "Size": 14.61
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\").replace(\"-\", \"/\")",
#                 "Size": 7.48
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.Substr(0,-3), (ifEqual(\"morning\",arg_1) then \" AM\" else \" PM\"))",
#                 "Size": 12.45
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(arg_0.Substr(2,-4), \"/\"), arg_0.Substr(0,2)), concat(\"/\", arg_0.Substr(-4,15)))",
#                 "Size": 18.05
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat((ifarg_0.Contain(\"-\") then \"\" else \"+\"), arg_0)",
#                 "Size": 8.99
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifarg_0.Contain(\"-\") then concat(arg_0.replace(\"-\", \"(\"), \")\") else arg_0)",
#                 "Size": 12.18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.Substr(0,15), \"\".lower().replace(arg_0.Substr(-1,15), \"...\"))",
#                 "Size": 13.01
#             }
#         ],
#         "1": [
#             {
#                 "Iteration": 1,
#                 "Program": "arg_1.Substr(0,arg_1.IndexOf(\" \"))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_1.Length(),15)",
#                 "Size": 5.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Length().IntToStr()",
#                 "Size": 3.01
#             },
#             {
#                 "Iteration": 4,
#                 "Program": "(ifarg_1.replace(\" \", \"yes\").Contain(\" \") then (ifEqual(arg_0.Length(),arg_1.Length()) then \"yes\" else \"no\") else (ifarg_1.Contain(arg_0.Substr(3,-4)) then (ifarg_1.Contain(arg_0.Substr(-4,2).lower()) then (ifEqual(arg_0.Length(),arg_1.Length()) then \"yes\" else \"no\") else \"no\") else \"no\"))",
#                 "Size": 10.690000000000001
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\"/\",(-3 * -3)),arg_0.Length())",
#                 "Size": 12.01
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "arg_0.replace(arg_0.replace((if\" \".Contain(arg_1.Substr(2,3)) then arg_0 else arg_1), concat(\" \", \" \")), arg_1)",
#                 "Size": 9.030000000000001
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifconcat(arg_0, concat(\"true\", \"false\")).lower().Contain(arg_0) then \"true\" else \"false\")",
#                 "Size": 12.47
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(\"NONE\",arg_0) then arg_1 else arg_0)",
#                 "Size": 6.67
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((arg_0.IndexOf(\" \") + 1),arg_0.Length())",
#                 "Size": 10.12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().replace(arg_0.lower().CharAt(0), arg_0.upper().CharAt(0))",
#                 "Size": 11.26
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"com\", \"org\")",
#                 "Size": 4.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.CharAt(0), arg_0.CharAt((arg_0.IndexOf(\" \") + 1))).upper()",
#                 "Size": 13.87
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_1) then \"yes\" else \"no\")",
#                 "Size": 7.55
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat(concat(concat(concat(concat(arg_0, \"0\"), \"0\"), \"0\").Substr(-3,(1 + 4)), arg_0).Substr(-4,1), concat(concat(concat(concat(arg_0, \"0\"), \"0\"), \"0\").Substr(-3,(1 + 4)), arg_0))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.replace(\" \", \"Mr. \"), \"Mr. \").Substr(arg_0.IndexOf(\" \"),-4)",
#                 "Size": 20.61
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(0,(arg_1.Length() * -1))",
#                 "Size": 7.06
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(concat(arg_0.CharAt(0), arg_1), \"@\"), arg_2).lower(), \".com\")",
#                 "Size": 12.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((1 + 4),15).replace(\"-\", \"/\")",
#                 "Size": 10.89
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((arg_0.IndexOf(\"/\") + 2),arg_0.IndexOf(\"/\",(-4 + -4)))",
#                 "Size": 17.38
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0, (ifarg_0.Contain(\".\") then \"\" else \".0\"))",
#                 "Size": 9.15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().replace(concat(\"\".lower(), arg_0), arg_0.upper())",
#                 "Size": 9.03
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\" \"),arg_0.Length()).replace(\" \", \"Ms. \").replace(\"Ms. \", (ifEqual(\"male\",arg_1) then \"Mr. \" else \"Ms. \"))",
#                 "Size": 10.469999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.Substr(0,-3), (ifEqual(\"morning\",arg_1) then \" AM\" else \" PM\"))",
#                 "Size": 12.48
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\").replace(\"-\", \"/\")",
#                 "Size": 7.71
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"<COMPANY>\", arg_1).replace(\"<COMPANY>\", arg_1).replace(\"<COMPANY>\", arg_1)",
#                 "Size": 10.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.CharAt(0), arg_0.CharAt((arg_0.IndexOf(\" \") + 1)))",
#                 "Size": 12.58
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(arg_0.replace(\"0%\", \"Not Yet Started\"), \"In Progress\").replace(\"100%\", \"Completed\").replace(\"0%\", \"Not Yet Started\")",
#                 "Size": 13.09
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.Substr(0,15), \"\".lower().replace(arg_0.Substr(-1,15), \"...\"))",
#                 "Size": 13.01
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifarg_0.Contain(\"-\") then concat(arg_0.replace(\"-\", \"(\"), \")\") else arg_0)",
#                 "Size": 12.219999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat((ifarg_0.Contain(\"-\") then \"\" else \"+\"), arg_0)",
#                 "Size": 9.2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(arg_0.Substr(2,-4), concat(concat(\"/\", arg_0.Substr(0,2)), \"/\")), arg_0.Substr(-4,15))",
#                 "Size": 18.07
#             }
#         ],
#         "4": [
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\"/\",(4 + 4)),arg_0.Length())",
#                 "Size": 11.14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0.replace(\" \", \"yes\").lower(),arg_1.replace(\" \", \"yes\").lower()) then \"yes\" else \"no\")",
#                 "Size": 14.52
#             },
#             {
#                 "Iteration": 5,
#                 "Program": "(ifarg_0.Substr(-3,15).Contain(\"/\") then (ifEqual(((4 % (-3 % arg_0.Length())) - (arg_0.Length() % -3)).IntToStr(),(ifarg_0.Substr(-4,-2).Contain(\"/\") then 2.IntToStr() else ((4 % (-3 % arg_0.Length())) - (arg_0.Length() % -3)).IntToStr())) then (ifarg_0.Substr(-4,15).Contain(\"/\") then (ifEqual((-4 % arg_0.Length()),2) then 2.IntToStr() else ((4 % (-3 % arg_0.Length())) - (arg_0.Length() % -3)).IntToStr()) else ((4 % (-3 % arg_0.Length())) - (arg_0.Length() % -3)).IntToStr()) else 3.IntToStr()) else (ifarg_0.Substr(-4,-2).Contain(\"/\") then 2.IntToStr() else ((4 % (-3 % arg_0.Length())) - (arg_0.Length() % -3)).IntToStr()))",
#                 "Size": 10.64
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_1.Length(),15)",
#                 "Size": 5.140000000000001
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Length().IntToStr()",
#                 "Size": 3.01
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_1.Substr(0,arg_1.IndexOf(\" \"))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_1) then \"yes\" else \"no\")",
#                 "Size": 6.37
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat(concat(concat(arg_0, concat(concat(\"0\", \"0\"), \"0\")).Substr(-3,(1 + 4)), arg_0).Substr(-4,1), concat(concat(arg_0, concat(concat(\"0\", \"0\"), \"0\")).Substr(-3,(1 + 4)), arg_0))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((arg_0.IndexOf(\" \") + 1),arg_0.Length())",
#                 "Size": 9.09
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.upper().CharAt(0), arg_0.lower().Substr(1,arg_0.Length()))",
#                 "Size": 11.02
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"com\", \"org\")",
#                 "Size": 4.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.CharAt(0), arg_0.CharAt((arg_0.IndexOf(\" \") + 1))).upper()",
#                 "Size": 15.46
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifconcat(arg_0, concat(\"false\", \"true\")).lower().Contain(arg_0) then \"true\" else \"false\")",
#                 "Size": 11.64
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(\"NONE\",arg_0) then arg_1 else arg_0)",
#                 "Size": 6.470000000000001
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_1.replace(arg_1.replace(arg_0.Substr(0,-3), arg_1.Substr(0,-2)), arg_0)",
#                 "Size": 13.22
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().replace(arg_0.replace(\" \", arg_0), arg_0.upper())",
#                 "Size": 9.0
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "concat(concat(arg_0.Substr(arg_0.IndexOf(\" \"),15).replace(\" \", \"Mr. \").replace(\"Mr. \", (ifEqual(\"male\",arg_1) then \"Mr. \" else \"Ms. \")), arg_0.Substr(15,-1)), arg_0.Substr(arg_0.IndexOf(\" \"),15).replace(\" \", \"Mr. \").replace(\"Mr. \", (ifEqual(\"male\",arg_1) then \"Mr. \" else \"Ms. \")).replace(concat(arg_0.Substr(arg_0.IndexOf(\" \"),15).replace(\" \", \"Mr. \").replace(\"Mr. \", (ifEqual(\"male\",arg_1) then \"Mr. \" else \"Ms. \")), arg_0.Substr(15,-1)), \"\").Substr(-3,-2))",
#                 "Size": 9.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((arg_0.IndexOf(\"/\") + 2),arg_0.IndexOf(\"/\",(-3 * -3)))",
#                 "Size": 14.870000000000001
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0, (ifarg_0.Contain(\".\") then \"\" else \".0\"))",
#                 "Size": 8.35
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((1 + 4),15).replace(\"-\", \"/\")",
#                 "Size": 11.58
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat(arg_0.Substr(arg_0.IndexOf(\" \"),15).replace(\" \", \"Mr. \"), concat(arg_0.replace(\" \", \"Mr. \"), \"Mr. \").Substr(15,-4).Substr(3,15))",
#                 "Size": 14.16
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(0,(arg_1.Length() * -1))",
#                 "Size": 7.2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.CharAt(0), concat(arg_1, concat(\"@\", concat(arg_2, \".com\")))).lower()",
#                 "Size": 12.01
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat((ifarg_0.Contain(\"-\") then \"\" else \"+\"), arg_0)",
#                 "Size": 8.18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(arg_0.Substr(2,-4), \"/\"), arg_0.Substr(0,2)), concat(\"/\", arg_0.Substr(-4,15)))",
#                 "Size": 18.02
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.Substr(0,15), \"\".lower().replace(arg_0.Substr(-1,15), \"...\"))",
#                 "Size": 13.04
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.replace(\"-\", \"(\"), (ifarg_0.Contain(\"-\") then \")\" else \"\"))",
#                 "Size": 11.629999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"<COMPANY>\", arg_1).replace(\"<COMPANY>\", arg_1).replace(\"<COMPANY>\", arg_1)",
#                 "Size": 10.1
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.CharAt(0), arg_0.CharAt((arg_0.IndexOf(\" \") + 1)))",
#                 "Size": 13.66
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(if\"100%\".Contain(arg_0) then arg_0 else \"In Progress\").replace(\"100%\", \"Completed\").replace(\"0%\", \"Not Yet Started\")",
#                 "Size": 13.14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.Substr(0,-3), (ifEqual(\"morning\",arg_1) then \" AM\" else \" PM\"))",
#                 "Size": 11.469999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\").replace(\"-\", \"/\")",
#                 "Size": 9.440000000000001
#             }
#         ],
#         "5": [
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\"/\",(-3 * -3)),arg_0.Length())",
#                 "Size": 10.219999999999999
#             },
#             {
#                 "Iteration": 4,
#                 "Program": "(ifEqual(arg_0.Substr(2,-3),\"/\") then 3.IntToStr() else ((ifarg_0.Substr(1,-1).Contain(\"/\") then 2 else 1).IntToStr().StrToInt() * ((3 + 4) - arg_0.Length()).IntToStr().Length()).IntToStr()).replace(3.IntToStr(), (ifEqual(arg_0.Substr(4,-1),\"/\") then 3.IntToStr() else ((ifarg_0.Substr(1,-1).Contain(\"/\") then 2 else 1).IntToStr().StrToInt() * ((3 + 4) - arg_0.Length()).IntToStr().Length()).IntToStr()))",
#                 "Size": 5.07
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_1.replace(\" \", \"yes\").lower(),arg_0.replace(\" \", \"yes\").lower()) then \"yes\" else \"no\")",
#                 "Size": 14.25
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Length().IntToStr()",
#                 "Size": 3.06
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_1.Length(),15)",
#                 "Size": 5.0600000000000005
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_1.Substr(0,arg_1.IndexOf(\" \"))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat(concat(concat(concat(concat(arg_0, \"0\"), \"0\"), \"0\").Substr(-3,(1 + 4)), arg_0).Substr(-4,1), concat(concat(concat(concat(arg_0, \"0\"), \"0\"), \"0\").Substr(-3,(1 + 4)), arg_0))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_1) then \"yes\" else \"no\")",
#                 "Size": 6.17
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.CharAt(0), arg_0.CharAt((arg_0.IndexOf(\" \") + 1))).upper()",
#                 "Size": 14.21
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"com\", \"org\")",
#                 "Size": 4.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.upper().CharAt(0), arg_0.lower().Substr(1,arg_0.Length()))",
#                 "Size": 14.73
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((arg_0.IndexOf(\" \") + 1),arg_0.Length())",
#                 "Size": 11.440000000000001
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(\"NONE\",arg_0) then arg_1 else arg_0)",
#                 "Size": 6.37
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifconcat(concat(\"false\", \"true\"), arg_0).lower().Contain(arg_0) then \"true\" else \"false\")",
#                 "Size": 11.37
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat((ifEqual(\"male\",arg_1) then \"Mr. \" else \"Ms. \").replace(\" \", arg_0.Substr(arg_0.IndexOf(\" \"),15)), arg_0.Substr(15,arg_0.Length()))",
#                 "Size": 12.7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().replace(concat(\"\".lower(), arg_0), arg_0.upper())",
#                 "Size": 9.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0, (ifarg_0.Contain(\".\") then \"\" else \".0\"))",
#                 "Size": 8.34
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((arg_0.IndexOf(\"//\") + 2),arg_0.IndexOf(\"/\",(-3 * -3)))",
#                 "Size": 14.34
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"\").replace(\"-\", \"/\").Substr(4,15)",
#                 "Size": 12.35
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.CharAt(0), concat(arg_1, concat(\"@\", concat(arg_2, \".com\")))).lower()",
#                 "Size": 12.01
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(0,(arg_1.Length() * -1))",
#                 "Size": 7.2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.replace(\" \", \"Mr. \"), \"Mr. \").Substr(arg_0.IndexOf(\" \"),-4)",
#                 "Size": 19.259999999999998
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(arg_0.Substr(2,-4), \"/\"), arg_0.Substr(0,2)), concat(\"/\", arg_0.Substr(-4,15)))",
#                 "Size": 18.02
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat((ifarg_0.Contain(\"-\") then \"\" else \"+\"), arg_0)",
#                 "Size": 8.2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.replace(\"-\", \"(\"), (ifarg_0.Contain(\"-\") then \")\" else \"\"))",
#                 "Size": 11.26
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.Substr(0,15), \"\".lower().replace(arg_0.Substr(-1,15), \"...\"))",
#                 "Size": 13.02
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(if\"100%\".Contain(arg_0) then (ifEqual(\"0%\",arg_0) then \"Not Yet Started\" else \"Completed\") else \"In Progress\")",
#                 "Size": 11.9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.CharAt(0), arg_0.CharAt((arg_0.IndexOf(\" \") + 1)))",
#                 "Size": 12.9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"<COMPANY>\", arg_1).replace(\"<COMPANY>\", arg_1).replace(\"<COMPANY>\", arg_1)",
#                 "Size": 10.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\").replace(\"-\", \"/\")",
#                 "Size": 7.71
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.Substr(0,-3), (ifEqual(\"morning\",arg_1) then \" AM\" else \" PM\"))",
#                 "Size": 11.82
#             }
#         ],
#         "2": [
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Length().IntToStr()",
#                 "Size": 3.15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_1.Length(),15)",
#                 "Size": 5.1899999999999995
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_1.Substr(0,arg_1.IndexOf(\" \"))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(arg_0.IndexOf(\"/\",(4 + 4)),arg_0.Length())",
#                 "Size": 12.23
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_1.replace(\" \", \"yes\").lower(),arg_0.replace(\" \", \"yes\").lower()) then \"yes\" else \"no\")",
#                 "Size": 15.44
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifconcat(arg_0, concat(\"true\", \"false\")).lower().Contain(arg_0) then \"true\" else \"false\")",
#                 "Size": 11.96
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(\"NONE\",arg_0) then arg_1 else arg_0)",
#                 "Size": 6.08
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "(ifarg_1.Contain(arg_0) then arg_1 else (ifEqual(arg_0.Substr(0,-4),arg_1.Substr(-2,1)) then arg_1 else arg_0))",
#                 "Size": 6.0600000000000005
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat(concat(concat(concat(concat(arg_0, \"0\"), \"0\"), \"0\").Substr(-3,(1 + 4)), arg_0).Substr(-4,1), concat(concat(concat(concat(arg_0, \"0\"), \"0\"), \"0\").Substr(-3,(1 + 4)), arg_0))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifEqual(arg_0,arg_1) then \"yes\" else \"no\")",
#                 "Size": 7.18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((arg_0.IndexOf(\" \") + 1),arg_0.Length())",
#                 "Size": 9.57
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.upper().CharAt(0), arg_0.lower().Substr(1,arg_0.Length()))",
#                 "Size": 11.24
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.CharAt(0), arg_0.CharAt((arg_0.IndexOf(\" \") + 1))).upper()",
#                 "Size": 14.13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"com\", \"org\")",
#                 "Size": 4.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((1 + 4),15).replace(\"-\", \"/\")",
#                 "Size": 11.91
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr(0,(arg_1.Length() * -1))",
#                 "Size": 7.09
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.replace(\" \", \"Mr. \"), \" \").Substr(arg_0.IndexOf(\" \"),-1)",
#                 "Size": 21.54
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(concat(arg_0.CharAt(0), arg_1), \"@\"), arg_2).lower(), \".com\")",
#                 "Size": 12.0
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat((ifEqual(\"male\",arg_1) then \"Mr. \" else \"Ms. \").replace(\" \", arg_0.Substr(arg_0.IndexOf(\" \"),15)), arg_0.Substr(15,arg_0.Length()))",
#                 "Size": 13.42
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.lower().replace(arg_0.replace(\" \", arg_0), arg_0.upper())",
#                 "Size": 9.03
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.Substr((arg_0.IndexOf(\"//\") + 2),arg_0.IndexOf(\"/\",(-4 + -4)))",
#                 "Size": 16.47
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0, (ifarg_0.Contain(\".\") then \"\" else \".0\"))",
#                 "Size": 8.32
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.CharAt(0), arg_0.CharAt((arg_0.IndexOf(\" \") + 1)))",
#                 "Size": 12.4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"<COMPANY>\", arg_1).replace(\"<COMPANY>\", arg_1).replace(\"<COMPANY>\", arg_1)",
#                 "Size": 10.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"100%\", \"Completed\").replace(\"0%\", \"Not Yet Started\").replace(arg_0.lower(), \"In Progress\")",
#                 "Size": 12.809999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.Substr(0,-3), (ifEqual(\"morning\",arg_1) then \" AM\" else \" PM\"))",
#                 "Size": 12.26
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "arg_0.replace(\"-\", \"/\").replace(\"-\", \"/\")",
#                 "Size": 8.25
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat((ifarg_0.Contain(\"-\") then \"\" else \"+\"), arg_0)",
#                 "Size": 8.24
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(arg_0.Substr(2,-4), concat(\"/\", arg_0.Substr(0,2))), concat(\"/\", arg_0.Substr(-4,15)))",
#                 "Size": 18.03
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.Substr(0,15), \"\".lower().replace(arg_0.Substr(-1,15), \"...\"))",
#                 "Size": 13.01
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(arg_0.replace(\"-\", \"(\"), (ifarg_0.Contain(\"-\") then \")\" else \"\"))",
#                 "Size": 11.309999999999999
#             }
#         ]
#     },
#     "89": {
#         "5": [
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,(_arg_0.IndexOf(\"/\",(3 * 3)) + (_arg_0.Length() % 2)))",
#                 "Size": 25.93
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(_arg_0.CharAt(0), concat(_arg_1, \"_\")), _arg_2)",
#                 "Size": 9.01
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr(4,(2 + 5))",
#                 "Size": 6.05
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(name.CharAt(0), \".\"), name.CharAt((name.IndexOf(\" \") + 1))), \".\")",
#                 "Size": 17.43
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\",\", \"\").replace(\"1\", \"apple\").replace(\"2\", \"bananas\").replace(\"3\", \"strawberries\").replace(\"4\", \"oranges\")",
#                 "Size": 18.86
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(col1, concat(\",\", concat(\" \", concat(col2.replace(concat(\",\", concat(\" \", \"USA\")), col1.Substr(1,0)), concat(\",\", concat(\" \", \"USA\"))))))",
#                 "Size": 23.04
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\"_\") + \"2\".StrToInt()),_arg_0.Length())",
#                 "Size": 10.26
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr(1,name.Length()).replace(\"-\", \".\").replace(\" \", \".\").replace(\"-\", \".\")",
#                 "Size": 16.71
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\" \") + 1),_arg_0.Length())",
#                 "Size": 9.39
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"DRS\", \"Direct Response\").replace(\"BRD\", \"Branding\").replace(\"LDS\", \"Leads\")",
#                 "Size": 10.059999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(ifcol2.Contain(\"USA\") then col2 else concat(col2, concat(\",\", concat(\" \", \"USA\"))))",
#                 "Size": 12.5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr(0,3)",
#                 "Size": 4.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,(_arg_0.IndexOf(\"Inc\") + -1))",
#                 "Size": 8.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(_arg_0.lower(), _arg_1)",
#                 "Size": 5.16
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(_arg_0.Substr(1,_arg_0.IndexOf(\" \")), \"\")",
#                 "Size": 12.06
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(\"Dr.\", \" \"), name.Substr(0,name.IndexOf(\" \")))",
#                 "Size": 15.68
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,_arg_0.IndexOf(\" \"))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(concat(concat(concat(_arg_0, \",\"), \" \").replace(concat(concat(concat(_arg_0, \",\"), \" \"), _arg_1), _arg_0), _arg_1), \",\"), \" \"), _arg_2)",
#                 "Size": 22.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr((3 + 5),name.Length())",
#                 "Size": 7.08
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,_arg_0.IndexOf(\" \",(\"ssp.\".Length() + \"ssp.\".Length())))",
#                 "Size": 13.16
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(col1, \",\"), \" \"), col2)",
#                 "Size": 7.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,(_arg_0.IndexOf(\"-\") + -1))",
#                 "Size": 8.030000000000001
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((-1 - (_arg_0.IndexOf(\"/\") + 1)),_arg_0.Length()).replace(\"/\", \"\")",
#                 "Size": 14.58
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "(if_arg_0.Contain(_arg_0.Substr((_arg_0.IndexOf(\" \") + 3),_arg_0.Length()).replace(\" \", \"\").Substr(0,4)) then _arg_0.Substr((_arg_0.IndexOf(\" \") + 3),_arg_0.Length()).replace(\" \", \"\").Substr(0,4) else _arg_0).Substr((1 - 5),_arg_0.Length())",
#                 "Size": 12.43
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr((0 - 3),name.Length())",
#                 "Size": 7.069999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.replace(\"-\", \".\").replace(\"-\", \".\")",
#                 "Size": 7.86
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr((name.IndexOf(\" \") + 1),name.Length())",
#                 "Size": 9.1
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_1.Substr(0,_arg_1.IndexOf(\"_\"))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(_arg_1.CharAt(0), _arg_0), \"_acme.com\")",
#                 "Size": 7.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(_arg_1.lower(), \"\").replace(_arg_1.upper(), \"\")",
#                 "Size": 21.72
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((-1 - (_arg_0.Length() % (_arg_0.IndexOf(\"=\") + -1))),_arg_0.Length())",
#                 "Size": 14.440000000000001
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(_arg_0, \" \"), _arg_1)",
#                 "Size": 5.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"(\", name.replace(\"-\", concat(\")\", \" \")))",
#                 "Size": 8.23
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "_arg_0.replace(\".\", \"\").replace(\".\", \"\").replace(\"-\", \"\").replace(\"<\", \"\").replace(\" \", \"\").replace(\">\", \"\").replace(\"-\", \"\")",
#                 "Size": 7.02
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr(0,name.IndexOf(\" \"))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(concat((if_arg_1.SuffixOf(_arg_0) then \" \" else \"\"), _arg_1), \"\")",
#                 "Size": 20.42
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\" \", \"-\").replace(\" \", \"-\")",
#                 "Size": 7.12
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat(concat(\" \", _arg_0), \" \").Substr(concat(_arg_0.CharAt(8), _arg_0).IndexOf(\" \"),-1).replace(concat(\" \", _arg_0), concat(concat(concat(\" \", _arg_0), \" \").Substr(concat(_arg_0.CharAt(8), _arg_0).IndexOf(\" \"),-1).Substr(0,9), \" \"))",
#                 "Size": 11.07
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(if_arg_0.Contain(\" \") then _arg_0.Substr(0,_arg_0.replace(\"|\", _arg_0).IndexOf(_arg_0)) else _arg_0)",
#                 "Size": 14.98
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(if_arg_0.Contain(\"windows\") then \"windows\" else (if\"/\".SuffixOf(_arg_0) then \"microsoft\" else \"mac\"))",
#                 "Size": 11.27
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr((name.IndexOf(\"-\") + 1),(0 - 4))",
#                 "Size": 10.41
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(lastname, concat(\" \", firstname))",
#                 "Size": 5.0
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "concat(_arg_0.Substr((-1 - _arg_0.IndexOf(\"/\")),-1).replace(\"/\", _arg_0.Substr(1,_arg_0.IndexOf(\"/\"))).replace(\" \", \"\"), (ifEqual(\"\",_arg_0.Substr((-1 - _arg_0.IndexOf(\"/\")),-1).replace(\"/\", _arg_0.Substr(1,_arg_0.IndexOf(\"/\"))).replace(\" \", \"\")) then \"\" else _arg_0).Substr(0,1)).lower().replace(_arg_0.Substr((-1 - _arg_0.IndexOf(\"/\")),-1).replace(\"/\", _arg_0.Substr(1,_arg_0.IndexOf(\"/\"))).replace(\" \", \"\"), _arg_0.Substr((-1 - _arg_0.IndexOf(\"/\")),-1).replace(\"/\", _arg_0.Substr(1,_arg_0.IndexOf(\"/\"))).replace(\" \", \"\").replace(_arg_0.Substr((-1 - _arg_0.IndexOf(\"/\")),-1).replace(\"/\", _arg_0.Substr(1,_arg_0.IndexOf(\"/\"))).replace(\" \", \"\").Substr(0,1), (ifEqual(\"\",_arg_0.Substr((-1 - _arg_0.IndexOf(\"/\")),-1).replace(\"/\", _arg_0.Substr(1,_arg_0.IndexOf(\"/\"))).replace(\" \", \"\")) then \"\" else _arg_0).Substr(0,1)))",
#                 "Size": 4.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\".\") + -1),((1 + 1) + _arg_0.IndexOf(\".\")))",
#                 "Size": 14.1
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(((\"9\".StrToInt() * 2) + -1),_arg_0.Length())",
#                 "Size": 10.43
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(concat(\" \", \" \"), \"\").replace(concat(\" \", \" \"), \" \")",
#                 "Size": 13.65
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_1.Substr((_arg_1.IndexOf(\"_\") + 1),_arg_1.Length())",
#                 "Size": 9.149999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,_arg_0.replace(\" \", _arg_0).IndexOf(_arg_0))",
#                 "Size": 17.490000000000002
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\" \",(_arg_0.IndexOf(\" \") + 1)) + 1),_arg_0.Length())",
#                 "Size": 14.17
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.replace(\" \", concat(\" \", \"(\")).replace(\"-\", concat(\")\", \" \"))",
#                 "Size": 12.26
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\" \") + 1),((1 - (-1 + -1)) * (-1 + -1)))",
#                 "Size": 16.810000000000002
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(((_arg_0.IndexOf(\"/\") + 1) + 1),_arg_0.Length())",
#                 "Size": 11.29
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(concat(_arg_0, \"/n\"), _arg_1), \"/n\"), _arg_2)",
#                 "Size": 9.01
#             },
#             {
#                 "Iteration": 4,
#                 "Program": "concat(col2.replace(concat(\" \", (ifcol2.Contain(\"NY\") then \"NY\" else \"New York\")), \"NY\").replace(concat(concat(\",\", \" \"), \"USA\"), \",\"), concat(\" \", \"USA\")).replace(\"CA\", concat(\"CA\", \",\")).replace(\"NY\", concat(\" \", \"NY\")).replace(concat(col2.replace(concat(\" \", (ifcol2.Contain(\"NY\") then \"NY\" else \"New York\")), \"NY\").replace(concat(concat(\",\", \" \"), \"USA\"), \",\"), concat(\" \", \"USA\")), concat(col2.replace(concat(\" \", (ifcol2.Contain(\"NY\") then \"NY\" else \"New York\")), \"NY\").replace(concat(concat(\",\", \" \"), \"USA\"), \",\"), concat(\" \", \"USA\")).replace(\"MD\", concat(\"MD\", \",\")).replace(\"NY\", concat(\" \", \"NY\")))",
#                 "Size": 4.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((-1 - ((1 + 1) + 1)),_arg_0.Length())",
#                 "Size": 11.18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(firstname, concat(\" \", lastname))",
#                 "Size": 5.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((-1 - ((1 + 1) + 1)),-1)",
#                 "Size": 10.59
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(((1 + 1) + _arg_0.IndexOf(\"=\")),_arg_0.Length())",
#                 "Size": 11.149999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"<\", \"\").replace(\">\", \"\").replace(\"<\", \"\").replace(\"<\", \"\").replace(\">\", \"\").replace(\">\", \"\")",
#                 "Size": 24.57
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(0.IntToStr(), _arg_0.CharAt(1)), \"/\"), _arg_0.Substr(_arg_0.IndexOf((1 + 1).IntToStr()),_arg_0.Length()))",
#                 "Size": 20.56
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,_arg_0.IndexOf(\".\"))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,((-1 - \"in\".Length()) * \"in\".Length()))",
#                 "Size": 10.84
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((-1 - (3 * 3)),_arg_0.Length())",
#                 "Size": 9.29
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(_arg_0.IndexOf(1.IntToStr(),((-1 + -1) - _arg_0.IndexOf(_arg_0.Substr(-1,_arg_0.Length())))),_arg_0.Length())",
#                 "Size": 22.95
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\".\") * -1),_arg_0.Length()).replace(\".\", \"\")",
#                 "Size": 12.07
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\" \",5) + 1),_arg_0.IndexOf(\" \",(4 * 4)))",
#                 "Size": 15.09
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\"_\") - 4),(_arg_0.IndexOf(\".\") + 4))",
#                 "Size": 14.68
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr(0,(0 - 3))",
#                 "Size": 6.279999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(firstname.CharAt(0), \".\"), \" \"), lastname)",
#                 "Size": 9.01
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\" \") + 1),_arg_0.Length())",
#                 "Size": 9.03
# ...
#                 "Size": 23.14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(lastname, concat(\" \", firstname))",
#                 "Size": 5.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr((name.IndexOf(\"-\") + 1),(0 - 4))",
#                 "Size": 10.8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(if_arg_0.Contain(\"microsoft\") then (if_arg_0.Contain(\"windows\") then \"windows\" else \"microsoft\") else \"mac\")",
#                 "Size": 16.47
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,(((_arg_0.replace(\"|\", _arg_0).IndexOf(_arg_0) + -1) % _arg_0.Length()) + 1))",
#                 "Size": 16.48
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "(ifEqual(_arg_0,_arg_0.replace(_arg_0.Substr(0,_arg_0.IndexOf(\" \")).upper(), \"\")) then concat(\" \", _arg_0.replace(_arg_0.Substr(0,_arg_0.IndexOf(\" \")).upper(), \"\").Substr(0,9)) else _arg_0.replace(_arg_0.Substr(0,_arg_0.IndexOf(\" \")).upper(), \"\"))",
#                 "Size": 12.54
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\" \", \"-\").replace(\" \", \"-\")",
#                 "Size": 7.3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(_arg_1.upper(), \"\").replace(concat(1.IntToStr(), \" \"), 1.IntToStr())",
#                 "Size": 22.67
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr(0,name.IndexOf(\" \"))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "_arg_0.replace(\".\", \"\").replace(\".\", \"\").replace(\"-\", \"\").replace(\"<\", \"\").replace(\">\", \"\").replace(\" \", \"\").replace(\"-\", \"\")",
#                 "Size": 4.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(\"(\", name.replace(\"-\", concat(\")\", \" \")))",
#                 "Size": 8.2
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(_arg_0, \" \"), _arg_1)",
#                 "Size": 5.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((-1 - (_arg_0.Length() % (_arg_0.IndexOf(\"=\") + -1))),_arg_0.Length())",
#                 "Size": 16.35
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(_arg_1.lower(), \"\").replace(_arg_1.lower(), \"\")",
#                 "Size": 16.310000000000002
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(_arg_1.CharAt(0), _arg_0), \"_acme.com\")",
#                 "Size": 7.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_1.Substr(0,_arg_1.IndexOf(\"_\"))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr((name.IndexOf(\" \") + 1),name.Length())",
#                 "Size": 9.43
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.replace(\"-\", \".\").replace(\"-\", \".\")",
#                 "Size": 7.86
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr((0 - 3),name.Length())",
#                 "Size": 7.14
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "_arg_0.Substr(_arg_0.IndexOf(_arg_0.Substr(_arg_0.IndexOf(1.IntToStr(),(_arg_0.IndexOf(\" \") + 3)),(3 * 5))),_arg_0.Length()).Substr(0,4)",
#                 "Size": 10.16
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((-1 - (_arg_0.IndexOf(\"/\") + 1)),_arg_0.Length()).replace(\"/\", \"\")",
#                 "Size": 17.009999999999998
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,(_arg_0.IndexOf(\"-\") + -1))",
#                 "Size": 8.02
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(col1, \",\"), \" \"), col2)",
#                 "Size": 7.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\".\") * -1),_arg_0.Length()).replace(\".\", \"\")",
#                 "Size": 12.3
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "_arg_0.Substr((\"/n\".Length() * (_arg_0.Length() % (-1 - (_arg_0.IndexOf(\" \") * \"/n\".Length())))),_arg_0.Length()).Substr(_arg_0.Substr((\"/n\".Length() * (_arg_0.Length() % (-1 - (_arg_0.IndexOf(\" \") * \"/n\".Length())))),_arg_0.Length()).IndexOf(1.IntToStr()),_arg_0.Substr((\"/n\".Length() * (_arg_0.Length() % (-1 - (_arg_0.IndexOf(\" \") * \"/n\".Length())))),_arg_0.Length()).Length())",
#                 "Size": 9.42
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((-1 - (3 * 3)),_arg_0.Length())",
#                 "Size": 9.33
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,_arg_0.IndexOf(\" \",(-1 - _arg_0.IndexOf(\" \"))))",
#                 "Size": 11.25
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,_arg_0.IndexOf(\".\"))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(0.IntToStr(), _arg_0.CharAt(1)), concat(\"/\", _arg_0.Substr(_arg_0.IndexOf((1 + 1).IntToStr()),_arg_0.Length())))",
#                 "Size": 22.080000000000002
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"<\", \"\").replace(\">\", \"\").replace(\"<\", \"\").replace(\"<\", \"\").replace(\">\", \"\").replace(\">\", \"\")",
#                 "Size": 24.46
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(((1 + 1) + _arg_0.IndexOf(\"=\")),_arg_0.Length())",
#                 "Size": 12.819999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((-1 - ((1 + 1) + 1)),-1)",
#                 "Size": 10.5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(firstname, concat(\" \", lastname))",
#                 "Size": 5.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((-1 - ((1 + 1) + 1)),_arg_0.Length())",
#                 "Size": 13.649999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(_arg_0, concat(\"/n\", concat(_arg_1, concat(\"/n\", _arg_2))))",
#                 "Size": 9.030000000000001
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(((1 + 1) + _arg_0.IndexOf(\"/\")),_arg_0.Length())",
#                 "Size": 11.799999999999999
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\" \") + 1),((1 - (-1 + -1)) * (-1 + -1)))",
#                 "Size": 17.36
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.replace(\" \", concat(\" \", \"(\")).replace(\"-\", concat(\")\", \" \"))",
#                 "Size": 14.54
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\" \",(_arg_0.IndexOf(\" \") + 1)) + 1),_arg_0.Length())",
#                 "Size": 17.17
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,_arg_0.replace(\" \", _arg_0).IndexOf(_arg_0))",
#                 "Size": 20.7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_1.Substr((_arg_1.IndexOf(\"_\") + 1),_arg_1.Length())",
#                 "Size": 9.36
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(concat(\" \", \" \"), \"\").replace(concat(\" \", \" \"), \" \")",
#                 "Size": 13.32
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((\"9\".StrToInt() - (1 - \"9\".StrToInt())),_arg_0.Length())",
#                 "Size": 13.83
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\".\") + -1),((1 + 1) + _arg_0.IndexOf(\".\")))",
#                 "Size": 14.09
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "concat(_arg_0.Substr((-1 - _arg_0.IndexOf(\"/\")),-1).replace(\" \", _arg_0.Substr(1,_arg_0.IndexOf(\"/\"))).replace(\"/\", \"\"), _arg_0.Substr(0,_arg_0.Substr((-1 - _arg_0.IndexOf(\"/\")),-1).replace(\" \", _arg_0.Substr(1,_arg_0.IndexOf(\"/\"))).replace(\"/\", \"\").Length()).Substr(0,1)).lower().replace(_arg_0.Substr((-1 - _arg_0.IndexOf(\"/\")),-1).replace(\" \", _arg_0.Substr(1,_arg_0.IndexOf(\"/\"))).replace(\"/\", \"\"), _arg_0.Substr((-1 - _arg_0.IndexOf(\"/\")),-1).replace(\" \", _arg_0.Substr(1,_arg_0.IndexOf(\"/\"))).replace(\"/\", \"\").replace(_arg_0.Substr((-1 - _arg_0.IndexOf(\"/\")),-1).replace(\" \", _arg_0.Substr(1,_arg_0.IndexOf(\"/\"))).replace(\"/\", \"\").Substr(0,1), _arg_0.Substr(0,_arg_0.Substr((-1 - _arg_0.IndexOf(\"/\")),-1).replace(\" \", _arg_0.Substr(1,_arg_0.IndexOf(\"/\"))).replace(\"/\", \"\").Length()).Substr(0,1)))",
#                 "Size": 4.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(lastname, concat(\",\", concat(\" \", concat(firstname.CharAt(0), \".\"))))",
#                 "Size": 11.08
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "concat(concat(concat(_arg_0.replace(\",\", \"\"), \",\"), _arg_0).replace(_arg_0.CharAt(1), \"\").Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(0,_arg_0.Length()), concat(concat(_arg_0.replace(\",\", \"\"), \",\"), _arg_0).replace(_arg_0.CharAt(1), \"\").Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(1,-1)).replace(concat(concat(_arg_0.replace(\",\", \"\"), \",\"), _arg_0).replace(_arg_0.CharAt(1), \"\").Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(1,-1), concat(concat(concat(_arg_0.replace(\",\", \"\"), \",\"), _arg_0).replace(_arg_0.CharAt(1), \"\").Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(0,-1), concat(concat(_arg_0.replace(\",\", \"\"), \",\"), _arg_0).replace(_arg_0.CharAt(1), \"\").Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(1,-1)).replace(concat(\",\", concat(concat(_arg_0.replace(\",\", \"\"), \",\"), _arg_0).replace(_arg_0.CharAt(1), \"\").Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(1,-1)), \"\").replace(concat(concat(_arg_0.replace(\",\", \"\"), \",\"), _arg_0).replace(_arg_0.CharAt(1), \"\").Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(1,-1), \"\")).replace(concat(concat(concat(_arg_0.replace(\",\", \"\"), \",\"), _arg_0).replace(_arg_0.CharAt(1), \"\").Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(0,-1), concat(concat(_arg_0.replace(\",\", \"\"), \",\"), _arg_0).replace(_arg_0.CharAt(1), \"\").Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(1,-1)).replace(concat(\",\", concat(concat(_arg_0.replace(\",\", \"\"), \",\"), _arg_0).replace(_arg_0.CharAt(1), \"\").Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(1,-1)), \"\").replace(concat(concat(_arg_0.replace(\",\", \"\"), \",\"), _arg_0).replace(_arg_0.CharAt(1), \"\").Substr(1,-1).Substr(1,-1).Substr(1,-1).Substr(1,-1), \"\"), \"\")",
#                 "Size": 9.02
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(_arg_0.IndexOf(\"_\"),concat(_arg_0, _arg_0).IndexOf(\" \",_arg_0.IndexOf(\"_\")))",
#                 "Size": 20.83
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"-\", \"\")",
#                 "Size": 4.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,concat(_arg_0, \" \").IndexOf(\" \",(\"Company\".Length() + 1)))",
#                 "Size": 18.64
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "concat(_arg_0.Substr((1 - 7),_arg_0.IndexOf((_arg_0.Length() * (_arg_0.Length() - (5 % (_arg_0.Length() % 9)))).IntToStr())), (_arg_0.Length() * (_arg_0.Length() - (5 % (_arg_0.Length() % 9)))).IntToStr())",
#                 "Size": 11.88
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_1.replace(_arg_1.replace(_arg_2.lower(), \" \"), _arg_0)",
#                 "Size": 8.08
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr(1,name.IndexOf(\" \"))",
#                 "Size": 6.0
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"that\".lower().replace(_arg_0.lower(), \"\"), \"\")",
#                 "Size": 10.82
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,(_arg_0.IndexOf(\"1\") + -1))",
#                 "Size": 8.030000000000001
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(((1 + 1) * (_arg_0.IndexOf(\"/\",((1 + 1) + 1)) + -1)),_arg_0.Length())",
#                 "Size": 21.1
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(_arg_0.IndexOf(0.IntToStr()),_arg_0.IndexOf(\"<\",1))",
#                 "Size": 10.08
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr((name.IndexOf(\"-\") - 3),name.IndexOf(\"-\"))",
#                 "Size": 10.25
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(firstname, concat(\" \", concat(lastname.CharAt(0), \".\")))",
#                 "Size": 9.02
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "(if_arg_0.Contain(_arg_2) then _arg_0 else _arg_1)",
#                 "Size": 7.68
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr(0,(_arg_0.replace(\"US\", \"CAN\").replace(\"CAN\", _arg_0).Length() % (_arg_0.Length() + 1)))",
#                 "Size": 16.34
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\"-\", \"\").replace(\"-\", \"\")",
#                 "Size": 8.84
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.replace(\">\", \"\").replace(\"<\", \" \").replace(\",\", \" \").replace(\",\", \" \")",
#                 "Size": 19.45
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\" \") + 1),_arg_0.Length())",
#                 "Size": 9.17
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "concat(concat(concat(firstname.CharAt(0), \".\"), \" \"), lastname)",
#                 "Size": 9.01
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "name.Substr(0,(0 - 3))",
#                 "Size": 6.24
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\"_\") - 4),(_arg_0.IndexOf(\".\") + 4))",
#                 "Size": 24.840000000000003
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "_arg_0.Substr((_arg_0.IndexOf(\" \",5) + 1),_arg_0.IndexOf(\" \",(4 * 4)))",
#                 "Size": 16.1
#             }
#         ]
#     }
# }

# %% [markdown]
# ## Crossbeam Log file processing

# %%
import json
results_cb = {}
for bn in ['new', 'sygus']:
    key = '38' if bn == 'new' else '89'
    results_cb[key] = {}
    for run in [1, 2, 3, 4, 5]:
        results_cb[key][run] = []
        for max_restart in [2, 4, 8]:
            result_file = '../../src_a_crossbeam/augmented/bustle_results/' + 'run_' + str(run) + '.'+str(max_restart) + '.grow-True.vw-bustle_sig-vsize.' + bn + '.json'
            res_json = json.load(open(result_file))
            for items in res_json['results']:
                iterations = items['attempt']
                is_success = items['success']
                program = items['solution']
                size = items['solution_weight']
                if is_success:
                    results_cb[key][run].append({"Iteration": iterations, "Program": program, "Size": size})
print(json.dumps(results_cb, indent=4))

# save the json to a file
with open('A-CB.json', 'w') as f:
    json.dump(results_cb, f)
# Out:
# {
#     "38": {
#         "1": [
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, Substitute(var_0, '.', '.0'), Concatenate(var_0, '.0'))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace('+', Find('-', Concatenate(var_0, '-')), 1, var_0)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Proper(Left(var_0, Find(',', var_0))), Upper(Right(var_0, 3)))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace(Lower(var_0), 1, 3, Proper(Left(var_0, 3)))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Exact(var_1, Lower(var_1)), Substitute(If(Exact(var_0, 'the text to search in'), 'FALSE', 'TRUE'), Left(var_1, 1), ''), 'TRUE')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Right(Left(Replace(To_Text(Len('the text to search in')), Len(var_1), 2, Left(To_Text(Add(3, Find(Trim(var_1), var_0))), 1)), Find(Right(var_1, 1), 'the text to search in')), Find(Left(var_1, 1), var_0))",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(Lower(var_0), 1), Concatenate(Lower(Concatenate(var_1, Concatenate('@', var_2))), '.com'))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Mid(var_0, 3, 2), Concatenate('/', Replace(var_0, 3, 2, '/')))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, '-', '/')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(Substitute(Mid(Right(var_0, Add(3, 3)), 2, 99), '-', Concatenate('/', Right(var_0, 2))), Add(2, 3))",
#                 "Size": 19
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Replace(Right(var_0, Minus(Minus(Minus(Len(Substitute(var_0, '://www.', '/')), Len('http://')), Len('http://')), 2)), 1, Find('/', Concatenate(Right(var_0, Minus(Minus(Minus(Len(Substitute(var_0, '://www.', '/')), Len('http://')), Len('http://')), 2)), '/')), '/')",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Left(var_1, Find(' ', Concatenate(var_0, var_1))))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(var_0, Lower(var_0)), 'true', 'false')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(var_0, Minus(Len(var_0), Find(' ', var_0)))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact('100%', var_0), 'Completed', If(Exact(var_0, '0%'), 'Not Yet Started', 'In Progress'))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(Concatenate(Substitute(var_0, '-', '('), ')'), Len(Substitute(var_0, '-', var_0)))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Mid(Concatenate(Rept('   ', Minus(Len(var_1), 1)), Concatenate(' ', var_0)), Len(To_Text(Len(var_0))), 99)",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Concatenate(Rept('000', Len(var_0)), Concatenate('000', var_0)), Add(2, 3))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Concatenate(To_Text(1), Rept(Substitute(To_Text(Len(Mid(var_0, 3, Add(3, 1)))), To_Text(3), ''), 3)), 1)",
#                 "Size": 19
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Find(var_0, Concatenate(var_1, var_0)), 99)",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Mid(Substitute(Substitute(var_0, ' ', Right(Trim('Mr. '), 2)), '.', 'Mr. '), 2, 99), Find(' ', var_0), 99)",
#                 "Size": 18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Lower(Trim(Concatenate(var_0, '   ')))",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Replace(var_0, Minus(Len('https://www.google.com/'), 2), 3, 'https://www.google.org/'), Len(var_0))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Gt(Len(var_1), Len('NONE')), Substitute(var_0, 'NONE', Substitute(Right(var_0, Len(var_1)), 'NONE', var_1)), var_0)",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Right(Left(Concatenate(var_1, var_0), Len(Concatenate(var_0, var_0))), Add(3, Len(var_0))), Len(Replace(var_1, 3, 1, ' ')))",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(var_1, var_0), 'yes', 'no')",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(Upper(var_0), Upper(var_1)), 'yes', 'no')",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "To_Text(Len(var_0))",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Minus(Len(var_0), Len(var_1)))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(var_0, Lower(var_0)), Upper(var_0), Lower(var_0))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Left(Concatenate(Left(var_0, Len(Rept(' text', 3))), Rept('.', 3)), Len(Left(var_0, Len(Rept(' lengt', 3)))))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Upper(Substitute(Concatenate(Left(var_0, 1), Left('Pr', 1)), Left(Concatenate(Left(var_0, 1), Left('Pr', 1)), 1), Right(var_0, 1), 2))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Upper(Substitute(var_0, ' ', Left(Lower(var_0), 1), 1)), Find(' ', var_0), 2)",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Left(Left(Concatenate(var_0, '.0'), Add(2, Find('.', Concatenate(var_0, '.')))), Find('0', Concatenate(var_0, '.0')))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace('+', Find('-', Concatenate(var_0, '-')), 1, var_0)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Proper(Lower(Left(var_0, Find(',', var_0)))), Right(Upper(var_0), 3))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace(Lower(var_0), 1, 2, Proper(Left(var_0, 2)))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Exact(var_1, Lower(var_1)), If(Exact(var_0, 'the text to search in'), 'FALSE', 'TRUE'), 'TRUE')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Mid(var_0, 3, 2), Concatenate('/', Replace(var_0, 3, 2, '/')))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, '-', '/')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(Right(var_0, Add(2, 3)), '-', '/')",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "Substitute(Left(Mid(var_0, Find(Mid(var_0, Add(3, Find(':', var_0)), Find('.', var_0)), var_0), Find(Right(Mid(var_0, Add(3, Find(':', var_0)), Find('.', var_0)), 3), var_0)), Find('/', Concatenate(Mid(var_0, Find(Mid(var_0, Add(3, Find(':', var_0)), Find('.', var_0)), var_0), Find(Right(Mid(var_0, Add(3, Find(':', var_0)), Find('.', var_0)), 3), var_0)), '://www.'))), '/', '')",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Right(Right(Right(var_0, Len(Substitute(Mid(var_0, Len(Substitute(var_0, 'http://', '/')), 99), '.', 'http', 1))), Add(2, Trim(Mid(var_0, Len(Substitute(var_0, 'http://', '/')), 99)))), Find(Right(var_0, 1), var_0))",
#                 "Size": 19
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Left(var_1, Find(' ', Concatenate(var_0, var_1))))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(var_0, Lower(var_0)), 'true', 'false')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(var_0, Minus(Len(var_0), Find(' ', var_0)))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "If(Gt(Len(If(Gt(Len('100%'), Len(var_0)), 'In Progress', 'Completed')), Len(If(Gt(Len(var_0), 2), Right(If(Gt(Len('100%'), Len(var_0)), 'In Progress', 'Completed'), Len('Completed')), 'Not Yet Started'))), 'In Progress', If(Gt(Len(var_0), 2), Right(If(Gt(Len('100%'), Len(var_0)), 'In Progress', 'Completed'), Len('Completed')), 'Not Yet Started'))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(Concatenate(Substitute(var_0, '-', '('), ')'), Len(Substitute(var_0, '-', var_0)))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Concatenate('000', Concatenate('000', var_0)), Add(2, 3))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Gte(Trim(To_Text(Find(Mid(var_0, 3, 1), Right(var_0, 3)))), Len(var_0)), To_Text(Find(Mid(var_0, 3, 1), Right(var_0, 3))), To_Text(Add(2, 2)))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Find(var_0, Concatenate(var_1, var_0)), 99)",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Right(Right(Substitute(Replace(var_0, 1, 2, 'ing'), ' ', 'Mr. '), Add(1, Len(Concatenate('Mr. ', Right(var_0, Minus(Find('ing', var_0), 3)))))), Minus(Len(var_0), 1))",
#                 "Size": 18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Lower(Trim(Concatenate(var_0, '  ')))",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, 'https://www.google.com/', 'https://www.google.org/')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Gte(3, Len(var_1)), var_0, Substitute(var_0, 'NONE', var_1))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Lower(If(Gte(Len(var_0), Len(var_1)), Upper(var_0), var_1))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(var_1, var_0), 'yes', 'no')",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(Proper(var_0), Proper(var_1)), 'yes', 'no')",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "To_Text(Len(var_0))",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Minus(Len(var_0), Len(var_1)))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(Lower(var_0), var_0, Upper(var_0))",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(Concatenate(Left(var_0, Len(Rept(' text', 3))), Rept('.', 3)), Len(var_0))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(var_0, 1), Mid(Substitute(var_0, ' ', ''), Find(' ', var_0), 1))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Upper(Lower(Substitute(var_0, ' ', Left(var_0, 1), 1))), Find(' ', var_0), 2)",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Left(Left(Concatenate(var_0, '.0'), Add(2, Find('.', Concatenate(var_0, '.')))), Find('0', Concatenate(var_0, '.0')))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Concatenate('+', var_0), Find(Substitute(var_0, '-', ''), var_0), 99)",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Proper(Left(var_0, Find(', ', var_0))), Right(Upper(var_0), 3))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace(Lower(var_0), 1, 3, Proper(Left(var_0, 3)))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Exact(var_1, Lower(var_1)), If(Exact('the text to search in', var_0), 'FALSE', 'TRUE'), 'TRUE')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Mid(var_0, 3, 2), Concatenate('/', Replace(var_0, 3, 2, '/')))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, '-', '/')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Right(Substitute(var_0, Right(var_0, 3), '/', 1), 3), Right(var_0, 2))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "Substitute(If(Gt(3, Find('.', Mid(var_0, Add(3, Find(':', var_0)), Find('.', var_0)))), Mid(var_0, Add(3, Find(':', var_0)), Find('.', var_0)), Mid(var_0, Find(Mid(var_0, Add(3, Find(':', var_0)), Find('.', var_0)), var_0), Find(Left('or', 1), var_0))), '/', '')",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "Right(Right(Right(var_0, Len(Substitute(Mid(var_0, Len(Substitute(var_0, 'http://', '/')), 99), '.', var_0))), Len(Concatenate('/', '://www.'))), Find(Right(Right(Right(var_0, Len(Substitute(Mid(var_0, Len(Substitute(var_0, 'http://', '/')), 99), '.', var_0))), Len(Concatenate('/', '://www.'))), 1), var_0))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Left(var_1, Find(' ', var_1)))",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(var_0, Minus(Len(var_0), Find(' ', var_0)))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Exact(var_0, '100%'), 'Completed', Substitute(Substitute(If(Gte(2, Len(var_0)), 'Not Yet Started', '0%'), '%', 'In Progress'), '0', ''))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Left(Concatenate(Substitute(var_0, '-', '('), ')'), Len(Substitute(var_0, '-', Right(var_0, 2))))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Concatenate('00', Concatenate('00', var_0)), Len(var_0), 99)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Left(Right(Replace(To_Text(Minus(2, Trim(To_Text(Find(Mid(var_0, 3, 1), Right(var_0, 3)))))), 1, 1, To_Text(Find(Mid(var_0, 3, 1), Right(var_0, 3)))), Minus(3, Len(To_Text(Len(var_0))))), 1)",
#                 "Size": 18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Find(var_0, Concatenate(var_1, var_0)), 99)",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Concatenate('Mr. ', Trim(Right(var_0, Minus(Len(Concatenate('Mr. ', Right(var_0, Minus(Find('ing', var_0), 3)))), 3))))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Lower(Trim(Replace(var_0, Len(var_0), 3, '')))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, 'https://www.google.com/', 'https://www.google.org/')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(Substitute(var_0, 'NONE', var_1), Proper(var_1), 'NONE')",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "If(Exact('aa', Substitute(var_0, Left(var_1, 2), var_1, 1)), 'aa', Substitute(If(Gt(Len(var_0), 3), var_0, var_1), Upper(If(Gt(Len(var_0), 3), var_0, var_1)), var_0))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Exact(var_1, var_0), Right(Concatenate('string', If(Exact(var_0, Lower(var_1)), 'yes', 'no')), 3), 'no')",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Exact(var_1, Lower(var_0)), 'yes', If(Gte(Len('match th'), Len(var_0)), 'yes', 'no'))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "To_Text(Len(var_0))",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Minus(Len(var_0), Len(var_1)))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(Upper(var_0), var_0, Lower(var_0))",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(var_0, 1), Trim(Mid(Concatenate(var_0, var_0), Find(' ', var_0), 2)))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Upper(Lower(Substitute(Left(Upper(Concatenate(Left(var_0, 1), 'pr')), 2), Right(Left(Upper(Concatenate(Left(var_0, 1), 'pr')), 2), 1), Right(var_0, 1), 2)))",
#                 "Size": 11
#             }
#         ],
#         "2": [
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(var_0, If(Exact(var_0, Substitute(var_0, '.', '.0')), '.0', ''))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace('+', Find('-', Concatenate(var_0, '-')), 1, var_0)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(Left(Concatenate(Substitute(var_0, ':00', If(Exact('morning', var_1), ' AM', ' ')), Trim(' PM')), Minus(Len(var_1), 1)), Len(var_0))",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace(Proper(var_0), Len(var_0), 1, Right(Upper(var_0), 1))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace(Lower(var_0), 1, 2, Proper(Left(var_0, 2)))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Substitute('FALSE', 'FALSE', 'TRUE', Minus(Len(Substitute(If(Exact(var_0, 'the text to search in'), 'FALSE', 'TRUE'), Left(var_1, 1), '')), 3))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Right(Concatenate(Right(Concatenate(To_Text(Len(var_1)), Rept(Mid(To_Text(Add(3, 1)), Len(var_1), 1), Add(3, 1))), Len(var_1)), Mid(Concatenate(Right(Concatenate(To_Text(Len(var_1)), Rept(Mid(To_Text(Add(3, 1)), Len(var_1), 1), Add(3, 1))), Len(var_1)), Right(To_Text(Len('the text to search in')), Len(Trim(var_1)))), 3, 1)), Find(Trim(var_1), var_1))",
#                 "Size": 19
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(Lower(var_0), 1), Lower(Concatenate(var_1, Concatenate('@', Concatenate(Lower(var_2), '.com')))))",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Mid(var_0, 3, 2), Concatenate('/', Substitute(var_0, Mid(var_0, 3, 2), '/', 1)))",
#                 "Size": 15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, '-', '/')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Substitute(var_0, '-', '/'), Add(3, 3), 99)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Left(Substitute(Mid(var_0, Find(Mid(var_0, Add(3, Find(':', var_0)), Find('.', var_0)), var_0), Len(Rept('www.', Trim(Mid(var_0, Add(3, Find(':', var_0)), Find('.', var_0)))))), '/', ''), Find('.', Substitute(var_0, 'www.', '')))",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Right(var_0, Find(If(Gt(Len('http://'), Find('/', var_0)), Right(var_0, 1), ''), var_0)), Len(Concatenate('://www.', ':')))",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Left(var_1, Find(' ', var_1, 3)))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(var_0, Lower(var_0)), 'true', 'false')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(var_0, Minus(Len(var_0), Find(' ', var_0)))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Gt(Len(var_0), 3), 'Completed', If(Exact(var_0, '0%'), 'Not Yet Started', 'In Progress'))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(Concatenate(Substitute(var_0, '-', '('), ')'), Len(Substitute(var_0, '-', var_0)))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Mid(Concatenate(Substitute('   ', '   ', '', Len(var_1)), Concatenate(' ', var_0)), Len(To_Text(Len(var_0))), 99)",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Mid(Concatenate('000', Concatenate('000', var_0)), 2, 99), Add(2, 3))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Gt(Trim(If(Gt(Len(var_0), Add(2, 2)), To_Text(1), To_Text(2))), Len(var_0)), If(Gt(Len(var_0), Add(2, 2)), To_Text(1), To_Text(2)), To_Text(Add(2, 2)))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Find(var_0, Concatenate(var_1, var_0)), 99)",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Substitute(Substitute(var_0, ' ', '.', 1), '.', 'Mr. '), Len(Rept(Left('Mr. ', 2), Find(' ', var_0))))",
#                 "Size": 17
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Lower(Trim(var_0))",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Mid(Substitute(Substitute(var_0, '.', ':', 2), Right('https://www.google.com/', 3), 'https://www.google.org/'), 3, 99), Len(var_0))",
#                 "Size": 16
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Gte(Len('NONE'), Len(var_0)), Left(Replace(var_0, 1, 3, If(Exact('NONE', var_0), var_1, Left(var_0, Len(var_1)))), Len(Substitute(var_0, 'NONE', var_1, 1))), var_0)",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Left(Concatenate(Left(If(Gt(Len(var_1), Len(var_0)), var_1, Substitute(var_0, ',', 'aa')), Add(3, 3)), ','), Len(If(Gt(Len(var_1), Len(var_0)), var_1, Substitute(var_0, ',', 'aa'))))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(var_1, var_0), 'yes', 'no')",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(If(Exact(Proper(var_0), Proper(var_1)), Concatenate(' ', 'yes'), 'no'))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "To_Text(Len(var_0))",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Minus(Len(var_0), Len(var_1)))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(var_0, Lower(var_0)), Upper(var_0), Lower(var_0))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(Concatenate(Left(var_0, Len(Rept(' text', 3))), Rept('.', 3)), Len(Left(var_0, Len(Rept(' lengt', 3)))))",
#                 "Size": 18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(var_0, 1), Trim(Mid(Upper(var_0), Find(' ', var_0), 2)))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Upper(Substitute(Upper(Lower(Concatenate(Left(var_0, 1), Left('pr', 1)))), Right(Upper(Lower(Concatenate(Left(var_0, 1), Left('pr', 1)))), 1), Right(var_0, 1), 2))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(var_0, If(Exact(var_0, Substitute(var_0, '.', '.0')), '.0', ''))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace('+', Find('-', Concatenate(var_0, '-')), 1, var_0)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(Proper(var_0), Find(', ', var_0)), Right(Upper(var_0), 3))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace(Lower(var_0), 1, 3, Left(Proper(var_0), 3))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Exact(var_1, Lower(var_1)), If(Exact('the text to search in', var_0), 'FALSE', 'TRUE'), 'TRUE')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "Right(Left(Concatenate(Substitute(Left(To_Text(Find(var_1, 'the text to search in')), 1), Left(To_Text(Find(var_1, 'the text to search in')), 1), To_Text(Add(3, 1)), Len(var_1)), Rept(Replace(To_Text(2), Find(Trim(var_1), var_1), Len(var_1), ''), 2)), Len(var_1)), 1)",
#                 "Size": 19
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(Lower(var_0), 1), Lower(Concatenate(Upper(Concatenate(var_1, Concatenate('@', var_2))), '.com')))",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, '-', '/')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Substitute(var_0, '-', '/'), Add(3, 3), 99)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "Left(Left(Replace(Substitute(var_0, '/', ''), 1, Find(':', var_0), ''), Find(Left('or', 1), var_0)), Minus(Minus(Find('/', var_0, Len(Left(Mid(var_0, Add(3, Find(':', var_0)), 99), Find('.', var_0)))), Trim(Left(Replace(Substitute(var_0, '/', ''), 1, Find(':', var_0), ''), Find(Left('or', 1), var_0)))), 2))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Find('/', var_0, Find('.', var_0)), 99)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Left(var_1, Find(' ', Concatenate(var_1, var_0))))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(var_0, Lower(var_0)), 'true', 'false')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(var_0, Minus(Len(var_0), Find(' ', var_0)))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Gt(Len('100%'), Len(var_0)), Proper(Lower(If(Gt(Len(var_0), 2), 'In Progress', Upper('Not Yet Started')))), 'Completed')",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(Concatenate(Substitute(var_0, '-', '('), ')'), Len(Substitute(var_0, '-', Left(var_0, 2), 1)))",
#                 "Size": 15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Replace('0', 2, 3, Concatenate('000', var_0)), Add(3, 2))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Find(var_0, Concatenate(var_1, var_0)), 99)",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Right(Mid(Substitute(Right(var_0, Find('ing', var_0)), ' ', 'Mr. ', 1), 2, Len(var_0)), Minus(Len(var_0), 1))",
#                 "Size": 18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Lower(Trim(var_0))",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Left(Substitute(Concatenate(var_0, Substitute(Substitute(Substitute(var_0, '.', Right(var_0, 1), 3), 'https://www.google.com/', 'https://www.google.org/'), '-', ':')), 'https://www.google.com/', 'https://www.google.org/'), Len(Substitute(Substitute(var_0, '.', Right(var_0, 1), 3), 'https://www.google.com/', 'https://www.google.org/')))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Gte(3, Len(var_1)), var_0, Right(Right(Substitute(Substitute(var_0, 'NONE', var_1), Proper(var_1), var_0), Len(Substitute(var_0, 'NONE', var_1))), Len(var_1)))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Left(Left(If(Gte(Len(var_0), Len(var_1)), var_0, Concatenate(var_1, var_1)), Len(Concatenate(var_1, ','))), Len(Replace(var_1, 3, 1, ',')))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(Substitute(var_0, var_1, 'yes'), var_0, 'no')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(Proper(var_1), Proper(var_0)), 'yes', 'no')",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "To_Text(Len(var_0))",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Minus(Len(var_0), Len(var_1)))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(var_0, Lower(var_0)), Upper(var_0), Lower(var_0))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(Concatenate(Left(var_0, Len(Rept(' text', 3))), Rept('.', 3)), Len(var_0))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Upper(Substitute(var_0, ' ', Lower(Left(var_0, 1)), 1)), Find(' ', var_0), 2)",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(Upper(var_0), 1), Trim(Mid(Upper(Concatenate(var_0, 'pr')), Find(' ', var_0), 2)))",
#                 "Size": 15
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Left(Left(Concatenate(var_0, '.0'), Add(2, Find('.', Concatenate(var_0, '.')))), Find('0', Concatenate(Left(Concatenate(var_0, '.0'), Add(2, Find('.', Concatenate(var_0, '.')))), '.0')))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace('+', Find('-', Concatenate(var_0, '-')), 1, var_0)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Proper(Replace(var_0, Len(var_0), 2, '')), Right(Upper(var_0), 1))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(Upper(var_0), 1), Mid(Lower(var_0), 2, 99))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Exact(var_0, Upper(var_0)), 'TRUE', If(Exact(var_1, Lower(var_1)), 'FALSE', 'TRUE'))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Gt(2, Find(Trim(var_1), var_1)), Left(Left(Concatenate(Left(To_Text(Add(3, 1)), Minus(2, Len(var_1))), To_Text(Find(var_1, 'the text to search in'))), Len(var_1)), 1), To_Text(2))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Mid(var_0, 3, 2), Concatenate('/', Replace(var_0, 3, 2, '/')))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, '-', '/')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Right(var_0, Find(If(Gt(Len('http://'), Find('/', var_0)), Right(var_0, 1), ''), var_0)), Len(Concatenate('://www.', ':')))",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Left(var_1, Find(' ', Concatenate(var_0, var_1))))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "If(Gte(3, Len(If(Exact(var_0, Lower(var_0)), 'true', Right('false', Len(var_0))))), 'false', If(Exact(var_0, Lower(var_0)), 'true', Right('false', Len(var_0))))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace(var_0, 1, Find(' ', var_0), '')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Proper(Lower(If(Gte(3, Len(var_0)), If(Exact(var_0, '0%'), 'Not Yet Started', 'In Progress'), Upper(Lower('Completed')))))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(Concatenate(Substitute(var_0, '-', '('), ')'), Len(Substitute(var_0, '-', var_0)))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Concatenate('00', Concatenate('00', var_0)), Len(var_0), 99)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Find(var_0, Concatenate(var_1, var_0)), 99)",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Concatenate('Mr. ', Right(var_0, Minus(Find('ing', var_0), 2))))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Lower(Trim(Concatenate(var_0, '  ')))",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Substitute(var_0, Right('https://www.google.com/', 3), 'https://www.google.org/'), Len(var_0))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact('NONE', Upper(var_0)), var_1, var_0)",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "Rept(Substitute(If(Gte(Add(3, 3), Len(var_0)), var_1, var_0), Upper(var_1), Right(var_0, 3)), Minus(3, Len(Left(var_1, 2))))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(var_1, var_0), 'yes', 'no')",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Exact(var_0, Lower(var_1)), 'yes', If(Gte(Len('match th'), Len(var_1)), 'yes', 'no'))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(If(Gte(Add(3, 3), Len(var_0)), To_Text(Add(3, 3)), To_Text(Minus(1, 99))), 1)",
#                 "Size": 17
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Minus(Len(var_0), Len(var_1)))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(Lower(var_0), var_0, Upper(var_0))",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Upper(Substitute(var_0, ' ', Left(var_0, 1), 1)), Find(' ', var_0), 2)",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Upper(Lower(Substitute(Upper(Concatenate(Left(var_0, 1), Left('pr', 1))), Right(Upper(Concatenate(Left(var_0, 1), Left('pr', 1))), 1), Right(var_0, 1), 2)))",
#                 "Size": 11
#             }
#         ],
#         "3": [
#             {
#                 "Iteration": 2,
#                 "Program": "Substitute(Left(Substitute(Concatenate(var_0, '.0'), '.', '', 2), Add(2, Find('.', Concatenate(var_0, '.')))), Replace(var_0, 1, 3, '.'), '.')",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace('+', Find('-', Concatenate(var_0, '-')), 1, var_0)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Proper(Left(var_0, Find(', ', var_0))), Right(Upper(var_0), 3))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace(Lower(var_0), 1, 2, Proper(Left(var_0, 2)))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Exact(var_1, Lower(var_1)), If(Exact('the text to search in', var_0), 'FALSE', 'TRUE'), 'TRUE')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Right(Concatenate(To_Text(Add(3, Minus(3, Len(Concatenate(var_1, var_1))))), Rept(Mid(To_Text(Find(Right(var_1, 1), 'the text to search in')), 2, 1), Find(var_1, var_0))), 1)",
#                 "Size": 17
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(Lower(var_0), 1), Lower(Concatenate(var_1, Concatenate('@', Concatenate(var_2, Proper('.com'))))))",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Mid(var_0, 3, 2), Concatenate('/', Replace(var_0, 3, 2, '/')))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, '-', '/')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(Right(var_0, Add(3, 2)), '-', '/')",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Substitute(Right(Right(Substitute(var_0, '.', '', 3), Add(1, Find(Substitute(var_0, 'http://', '/'), var_0))), Find(Right(var_0, 1), var_0)), Substitute(Right(Right(Substitute(var_0, '.', '', 3), Add(1, Find(Substitute(var_0, 'http://', '/'), var_0))), Find(Right(var_0, 1), var_0)), '/', '.', 2), '/')",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Left(var_1, Find(' ', Concatenate(var_0, var_1))))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(var_0, Lower(var_0)), 'true', 'false')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Replace(var_0, 1, Add(3, 3), ''))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Gt(Len(var_0), 3), 'Completed', If(Gt(Len(var_0), 2), 'In Progress', If(Exact('100%', var_0), 'In Progress', 'Not Yet Started')))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(Concatenate(Substitute(var_0, '-', '('), ')'), Len(Substitute(var_0, '-', var_0)))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Concatenate(Right('   ', Len(var_1)), Mid(Substitute(Concatenate(Left('   ', Minus(Len(var_0), 3)), var_0), Substitute(var_0, ' ', ''), Concatenate(' ', var_0), 1), 3, 99))",
#                 "Size": 18
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Substitute(Concatenate('000', var_0), '0', '000', 3), Add(3, 2))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Exact(var_0, Substitute(var_0, '/a/', '')), To_Text(1), To_Text(Add(1, Find(Mid(var_0, 3, 1), var_0))))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Find(var_0, Concatenate(var_1, var_0)), 99)",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Substitute(Proper(Substitute(var_0, ' ', Trim('Mr. '), 1)), '.', 'Mr. '), Len(Rept(Left('Mr. ', 2), Find(' ', var_0))))",
#                 "Size": 19
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Lower(Trim(var_0))",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Mid(Substitute(Concatenate(Left(Substitute(Substitute(var_0, '-', '/'), 'https://www.google.com/', 'https://www.google.org/'), 1), var_0), 'https://www.google.com/', 'https://www.google.org/'), 2, Len(Substitute(Substitute(var_0, '-', '/'), 'https://www.google.com/', 'https://www.google.org/')))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(If(Exact('NONE', Upper(var_0)), var_1, Proper(var_0)), Proper(var_0), var_0)",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Right(Right(Left(Concatenate(var_1, var_0), Len(Concatenate(var_0, var_0))), Len(Concatenate(var_1, ','))), Add(2, Find(Right(var_1, 3), var_1)))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(var_1, var_0), 'yes', 'no')",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Exact(Proper(var_0), Proper(var_1)), 'yes', 'no')",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "To_Text(Len(var_0))",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Minus(Len(var_0), Len(var_1)))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Substitute(Lower(var_0), Right(var_0, 2), Upper(var_0)), Len(var_0))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Left(Concatenate(Left(var_0, Len(Rept(' text', 3))), Rept('.', 3)), Len(var_0))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(var_0, 1), Trim(Mid(Rept(var_0, 3), Find(' ', var_0), 2)))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Upper(Lower(Substitute(var_0, ' ', Left(var_0, 1)))), Find(' ', var_0), 2)",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, Substitute(var_0, '.', '0'), Concatenate(var_0, '.0'))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace('+', Find('-', Concatenate(var_0, '-')), 1, var_0)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Proper(Left(var_0, Find(', ', var_0))), Right(Upper(var_0), 3))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace(Lower(var_0), 1, 2, Proper(Left(var_0, 2)))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "If(Exact(var_1, Lower(var_1)), If(Exact('the text to search in', var_0), 'FALSE', 'TRUE'), 'TRUE')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Right(Left(Concatenate(Mid(To_Text(Len(Concatenate(var_0, 'the text to search in'))), Len(var_1), 1), To_Text(Len(var_0))), Find(Trim(var_1), var_0)), 1)",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(Lower(var_0), 1), Lower(Concatenate(var_1, Concatenate('@', Concatenate(Lower(var_2), '.com')))))",
#                 "Size": 14
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Mid(var_0, 3, 2), Concatenate('/', Replace(var_0, 3, 2, '/')))",
# ...
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Replace(var_0, 1, Find(' Jane ', var_0), ''), Len(' Jane '), 99)",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Add(1, 3), Minus(Len(var_0), Add(3, 3)))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "Right(Concatenate(To_Text(Len(var_0)), If(Exact(Right(If(Gt(3, Find('00', var_0)), Concatenate(To_Text(1), '00'), Rept(var_0, 3)), Minus(Find(' ', var_0), 1)), Proper(Right(If(Gt(3, Find('00', var_0)), Concatenate(To_Text(1), '00'), Rept(var_0, 3)), Minus(Find(' ', var_0), 1)))), Right(If(Gt(3, Find('00', var_0)), Concatenate(To_Text(1), '00'), Rept(var_0, 3)), Minus(Find(' ', var_0), 1)), '00')), Len(Right(If(Gt(3, Find('00', var_0)), Concatenate(To_Text(1), '00'), Rept(var_0, 3)), Minus(Find(' ', var_0), 1))))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Mid(Right(Concatenate(' ', Trim(Substitute(var_0, Upper(Right(var_0, 3)), ' ', 1))), Minus(Len(var_0), 3)), Find(' ', Right(Concatenate(' ', Trim(Substitute(var_0, Upper(Right(var_0, 3)), ' ', 1))), Minus(Len(var_0), 3))), 99)",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Minus(Len(var_0), 3))",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate('Dr. ', Trim(Left(var_0, Find(' ', var_0))))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Left(var_0, Find(' ', var_0)))",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(var_0, 1), Concatenate('.', Concatenate(Trim(Mid(var_0, Find(' ', var_0), 2)), '.')))",
#                 "Size": 15
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace(var_0, 1, Find(' ', var_0), '')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Concatenate(var_0, ' '), Concatenate(Left(var_1, 1), '.'))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(var_0, 1), Concatenate('. ', var_1))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(var_1, Concatenate(', ', Concatenate(Left(var_0, 1), '.')))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(var_0, Concatenate(' ', var_1))",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Add(3, 2), 3)",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(var_0, 3)",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate('(', Substitute(Substitute(var_0, '-', ') '), ') ', '-', 2))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Substitute(Replace(var_0, Add(2, 2), 1, '.'), '-', '.')",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Trim(Left(var_0, Find(' ', var_0))), 2, 3)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Right(Mid(var_0, Len('72 0'), Find(' ', var_0)), 3)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(Right(var_0, Len(Concatenate('72 0', '-85'))), 3)",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(var_0, 3)",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, 3)",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(var_1, Concatenate(' ', var_0))",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(var_0, Concatenate(', ', var_1))",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "Substitute(Concatenate(var_1, ', USA'), ', USA', '', 2)",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(var_0, 2), Right(var_0, Add(3, 2)))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Replace(Substitute(var_0, Mid(var_0, 3, 2), ''), 2, 2, ' '))",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Minus(Find('-', var_0), 2))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Left(Trim(Left(var_0, Add(2, Len(Rept('TL-', 3))))), Add(2, Find('76', Concatenate(Trim(Left(var_0, Add(2, Len(Rept('TL-', 3))))), '76'))))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "Trim(Left(var_0, Add(1, Len(Left(Substitute(Left(var_0, Len('General Electric')), 'rp', ''), Len(If(Exact('General Electric', Substitute(Left(var_0, Len('General Electric')), 'rp', '')), Substitute(Left(var_0, Len('General Electric')), 'rp', ''), 'Nintendo')))))))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace(var_0, 1, Find(' ', var_0), '')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "If(Exact(If(Gte(Len(var_0), Len(Substitute(Substitute(var_0, 'dd', var_1, 1), Lower(var_0), var_1))), Substitute(Substitute(var_0, 'dd', var_1, 1), Lower(var_0), var_1), Left(Substitute(Substitute(var_0, 'dd', var_1, 1), Lower(var_0), var_1), 3)), Lower(If(Gte(Len(var_0), Len(Substitute(Substitute(var_0, 'dd', var_1, 1), Lower(var_0), var_1))), Substitute(Substitute(var_0, 'dd', var_1, 1), Lower(var_0), var_1), Left(Substitute(Substitute(var_0, 'dd', var_1, 1), Lower(var_0), var_1), 3)))), Substitute(If(Gte(Len(var_0), Len(Substitute(Substitute(var_0, 'dd', var_1, 1), Lower(var_0), var_1))), Substitute(Substitute(var_0, 'dd', var_1, 1), Lower(var_0), var_1), Left(Substitute(Substitute(var_0, 'dd', var_1, 1), Lower(var_0), var_1), 3)), 'abc', var_0), var_0)",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(Right(var_0, Add(1, Find('/', var_0))), '/', '')",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Gt(Len(var_2), Add(3, 2)), 'I hate bananas', 'I love apples')",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, Lower(Substitute('that', var_0, Proper('knowthat'))), '')",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Substitute(Trim(Substitute(var_0, '<', '')), '>', ''))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, '/delete words in the area /', '')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Minus(Find(' ', var_0, Len(' vulgaris')), 1))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Len(Concatenate(',', 'KOR.JPN<IDEALPRO,CASH,')), 3)",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(var_0, Concatenate(Concatenate('/n', var_1), Concatenate('/n', var_2)))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, '-', '')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(var_1, 1), Concatenate(var_0, '_acme.com'))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(var_0, 1), Concatenate(Concatenate(var_1, '_'), var_2))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Replace(var_1, 1, Find('_', var_1), '')",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(Right(var_0, 3), '.', '', 1)",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Find('= ', Concatenate('el', var_0)), 99)",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Mid(var_0, Find('/', var_0), 99), 3, 99)",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Right(Trim(Left(var_0, Find('.', Concatenate('.com', var_0), Len('.com')))), Add(2, Len(Rept('.com', 3)))))",
#                 "Size": 18
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Left(Mid(var_0, Find('_', var_0), Add(3, Len(' _name'))), Find('name', Concatenate('name', Mid(var_0, Find('_', var_0), Add(3, Len(' _name')))), 2))",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(Left(var_1, Find('_', var_1)), '_', '')",
#                 "Size": 8
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(Left(Left(var_0, Add(Len('abc.com'), Find('.', var_0))), Len(Substitute('http=//', '/', 'http=//'))), Find('/', var_0, Len('abc.com/def')))",
#                 "Size": 20
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Add(2, 3))",
#                 "Size": 5
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(Trim(Left(var_0, Find(' ', Concatenate(var_0, 'quick brown fox.'), 3))), var_0, '')",
#                 "Size": 12
#             },
#             {
#                 "Iteration": 2,
#                 "Program": "Mid(Right(var_0, Find('0', '11/1/2015 - First call/n12/3/2015-order placed', Find('-', '11/1/2015 - First call/n12/3/2015-order placed'))), Find(To_Text(1), Right(var_0, Find('0', '11/1/2015 - First call/n12/3/2015-order placed', Find('-', '11/1/2015 - First call/n12/3/2015-order placed')))), 99)",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(var_0, 3)",
#                 "Size": 3
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(var_0, Len(' is '))",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 4,
#                 "Program": "Trim(Substitute(If(Exact('an', Right(Mid(var_0, Add(1, Find(' ', var_0)), 3), 2)), '', Left(Mid(var_0, Find(Mid(var_0, Add(1, Find(' ', var_0)), 3), var_0), Lower(Mid(var_0, Add(1, Find(' ', var_0)), 3))), Find(Left(Mid(var_0, Add(1, Find(' ', var_0)), 3), 1), var_0))), Substitute(If(Exact('an', Right(Mid(var_0, Add(1, Find(' ', var_0)), 3), 2)), '', Left(Mid(var_0, Find(Mid(var_0, Add(1, Find(' ', var_0)), 3), var_0), Lower(Mid(var_0, Add(1, Find(' ', var_0)), 3))), Find(Left(Mid(var_0, Add(1, Find(' ', var_0)), 3), 1), var_0))), ' t', ' '), Mid(var_0, Add(1, Find(' ', var_0)), 3), 1))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "Substitute(Concatenate(var_0, Concatenate(var_1, Concatenate(',', Concatenate(' ', var_2)))), Right(var_1, 1), 's, ', 1)",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Concatenate(Left(var_0, Add(2, 2)), Concatenate('n ', var_1))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "If(Gte(Len(var_2), Len(var_0)), var_0, Trim(Left(var_1, 3)))",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Minus(Find('.', var_0), 1))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, '-', '')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Len(Concatenate(' ', 'c=/users/dave/')), 99)",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute('zx66448', var_1, '')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(var_0, ' 456 8756', '-456-8756')",
#                 "Size": 4
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Minus(Find(' ', var_0, Len('Trucking')), 1))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Mid(Mid(var_0, Find('_', var_0), 99), 2, 99))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Replace('ind', 2, 3, var_0), 2, Len(Replace(var_0, Find(' ', var_0), Add(3, 3), '')))",
#                 "Size": 17
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(' Westerkerk HRL', Len(Left(Substitute(var_0, 'geb. 14 oct 1956', ''), Len('Westerkerk HRL'))))",
#                 "Size": 10
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Left(var_0, Minus(Find('=191', var_0), 1))",
#                 "Size": 7
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(var_0, Find('loren', var_0), 99)",
#                 "Size": 6
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Trim(Replace(var_0, Find('AQ-', var_0), Len(var_1), ' '))",
#                 "Size": 9
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Mid(Replace(var_0, 1, Find(' ', var_0), ''), Len(' Jane '), 99)",
#                 "Size": 11
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Substitute(Right(Mid(Left(var_0, Minus(Len(var_0), 3)), 3, 99), Add(3, 3)), '>', '')",
#                 "Size": 16
#             },
#             {
#                 "Iteration": 3,
#                 "Program": "Right(Replace(To_Text(Len(var_0)), Find(Mid(var_0, Find('0', var_0), Minus(Find(' ', var_0), 1)), var_0), 1, Trim(Mid(var_0, Find('0', var_0), Minus(Find(' ', var_0), 1)))), Len(Mid(var_0, Find('0', var_0), Minus(Find(' ', var_0), 1))))",
#                 "Size": 13
#             },
#             {
#                 "Iteration": 1,
#                 "Program": "Right(Concatenate(' ', Trim(Substitute(var_0, Upper(Right(var_0, 3)), ''))), Minus(Len(Substitute(var_0, To_Text(3), '')), 3))",
#                 "Size": 19
#             }
#         ]
#     }
# }

# %% [markdown]
# ### process the A-BUS.json, A-Bee.json, A-Bustle.json and A-CB.json files and update the size of the programs

# %%
import json
import re


class ProgramParser:
    def parse_program(self, program_str):
        tokens = self.tokenize(program_str)
        parsed_program, _ = self.parse_tokens(tokens)
        return parsed_program

    def tokenize(self, program_str):
        # Step 1: Find all quoted strings and replace them with placeholders
        placeholders = {}
        def replace_with_placeholder(match):
            placeholder = f"__QUOTED{len(placeholders)}__"
            placeholders[placeholder] = match.group(0)
            return placeholder

        program_str = re.sub(r'"[^"]*"', replace_with_placeholder, program_str)

        # Step 2: Remove all commas and periods outside of quotes
        program_str = re.sub(r'(?<!\w)[,.](?!\w)', '', program_str)

        # Step 3: Replace placeholders with the original quoted strings
        for placeholder, quoted_str in placeholders.items():
            program_str = program_str.replace(placeholder, quoted_str)

        # Tokenize the modified string, including arithmetic operators
        tokens = re.findall(r'"[^"]*"|\w+|[\+\-\*/%]|\(|\)|\,|\.', program_str)
        return tokens

    def parse_tokens(self, tokens):
        parsed_program = []
        i = 0
        while i < len(tokens):
            token = tokens[i]
            if token in ['.', ',', '(', ')']:
                # Directly add punctuation tokens
                parsed_program.append(token)
                i += 1
            elif token.startswith('"') and token.endswith('"'):
                # Add string literals as is
                parsed_program.append(token)
                i += 1
            elif token.isalpha() or re.match(r'[\w\+\-\*/]', token):
                # Handle function names and variables
                if i + 1 < len(tokens) and tokens[i + 1] == '(':
                    # If the next token is '(', it's a function call
                    function_name = token
                    i += 2  # Move past function name and '('
                    args, new_index = self.parse_arguments(tokens, i)
                    i = new_index
                    parsed_program.append((function_name, args))
                else:
                    # Otherwise, it's a variable or standalone token
                    parsed_program.append(token)
                    i += 1
            else:
                # Unrecognized token
                i += 1
        return parsed_program, i

    def parse_arguments(self, tokens, start_index):
        args = []
        current_arg = []
        i = start_index
        while i < len(tokens) and tokens[i] != ')':
            if tokens[i] == ',':
                if current_arg:
                    args.append(current_arg)
                    current_arg = []
            else:
                current_arg.append(tokens[i])
            i += 1
        if current_arg:
            args.append(current_arg)
        return args, i + 1  # Return position after closing ')'

def remove_commas_periods(obj):
    if isinstance(obj, list):
        return [remove_commas_periods(x) for x in obj if x not in [',', '.']]
    elif isinstance(obj, tuple):
        # Apply the function to each element of the tuple
        return tuple(remove_commas_periods(x) for x in obj)
    else:
        return obj


def process_program_stack(program_object, stack_operators, stack_operands):
    for item in program_object:
        if isinstance(item, list):
            # Recursive call for nested structures
            process_program_stack(item, stack_operators, stack_operands)
        elif isinstance(item, tuple):
            # Increment count for the function call
            stack_operators.append(item[0])
            process_program_stack(item[1], stack_operators, stack_operands)
        elif item in list_operations:
            stack_operators.append(item)
        elif item == '(' or item == ')':
            # Increment count for parentheses
            stack_operands.append(item)
        else:
            # Increment count for operands
            stack_operands.append(item)

def process_program_object(program_object):
    node_count = 0
    i = 0
    while i < len(program_object):
        item = program_object[i]
        if isinstance(item, list):
            # Recursive call for nested structures
            node_count += process_program_object(item)
        elif isinstance(item, tuple):
            # Special handling for 'if .. then .. else' construct
            if item[0] == 'if' and i + 4 < len(program_object) and program_object[i + 2] == 'then' and program_object[i + 4] == 'else':
                node_count += 1  # Count the entire 'if .. then .. else' as one node
                node_count += process_program_object(item[1])  # Count the condition
                node_count += process_program_object(program_object[i + 3])  # Count the 'then' part
                node_count += process_program_object(program_object[i + 5])  # Count the 'else' part
                i += 6  # Skip past the entire 'if .. then .. else' construct
            else:
                # Count the operator itself
                node_count += 1
                # Count the arguments of the operator
                node_count += process_program_object(item[1])
        elif item in list_operations:
            # Count the operation
            node_count += 1
        elif isinstance(item, str) and not item in ['(', ')', ',', '.']:
            # Count operands (excluding parentheses, commas, and periods)
            node_count += 1
        else:
            i += 1
            continue  # Skip non-countable items
        i += 1

    return node_count

def count_size(program_str):
    parser = ProgramParser()
    total_nodes = None
    try:
        program_object = parser.parse_program(program_str)
        count_then_else = program_str.count('then') + program_str.count('else')
        # remove all the , and . from the program_object list that are not inside the quotes
        program_object = remove_commas_periods(program_object)
        # print(program_object)

        stack_operators = []
        stack_operands = []

        process_program_stack(program_object, stack_operators, stack_operands)
        print("Operators:", stack_operators)
        print("Operands:", stack_operands)

        total_nodes = process_program_object(program_object) - count_then_else
        # print("Size_" + str(count) + " = " + str(total_nodes))
    except:
        pass
    return total_nodes

def call_parser(algo, json_data = {}, operations = []):
    # Example usage
    global list_operations
    list_operations = operations
    
    # json result
    json_result = {}
    
    bns = ['89', '38']
    runs = ['1', '2', '3', '4', '5']
    for key in bns:
        if algo != 'A-BUS' and algo != 'BUS':
            json_result[key] = {}
            for cur_run in runs:
                json_result[key][cur_run] = []
                for entry in json_data[key][cur_run]:
                    program_str = entry["Program"]
                    iterations = entry["Iteration"]
                    program_size = count_size(program_str)
                    json_result[key][cur_run].append({"Iteration":iterations, "Program":program_str, "Size":program_size})
        else:
            json_result[key] = []
            for entry in json_data[key]:
                program_str = entry["Program"]
                iterations = entry["Iteration"]
                program_size = count_size(program_str)
                json_result[key].append({"Iteration":iterations, "Program":program_str, "Size":program_size})
    
    return json_result

# %%
# test count size
parser = ProgramParser()
global list_operations

program_str = "Substitute(var_0, Substitute(var_0, \".\", \".0\"), Concatenate(var_0, \".0\"))"

list_operations = [
      'Add',
      'Concatenate',
      'Find',
      'Left',
      'Len',
      'Mid',
      'Minus',
      'Replace',
      'Right',
      'Trim',
      'Lower',
      'Upper',
      'Proper',
      'Rept',
      'Substitute',
      'ToText',
      'If',
      'Exact',
      'Gt',
      'Gte',
  ]

count_size(program_str)
# Out:
# Operators: ['Substitute', 'Substitute', 'Concatenate']
# Operands: ['var_0', '(', 'var_0', '"."', '".0"', 'var_0', '".0"', ')']
# 9

# %%
# BUS

json_data = json.load(open("BUS.json"))
operations = ['concat', 'replace', 'upper', 'lower', 'Substr', 'IndexOf', 'Length', 'CharAt', '+', '-', '*', '/', '%', 'Contain', 'Equal', 'if', 'then', 'else', 'SuffixOf', 'PrefixOf', 'StrToInt', 'IntToStr', 'stip', 'title']
json_result = call_parser('BUS', json_data, operations)

# save the json to a file
with open('BUS-size.json', 'w') as f:
    json.dump(json_result, f)


# # A-BUS

# json_data = json.load(open("A-BUS.json"))
# operations = ['concat', 'replace', 'upper', 'lower', 'Substr', 'IndexOf', 'Length', 'CharAt', '+', '-', '*', '/', '%', 'Contain', 'Equal', 'if', 'then', 'else', 'SuffixOf', 'PrefixOf', 'StrToInt', 'IntToStr', 'stip', 'title']
# json_result = call_parser('A-BUS', json_data, operations)

# # # save the json to a file
# # with open('A-BUS-size.json', 'w') as f:
# #     json.dump(json_result, f)


# # A-Bustle
# json_data = json.load(open("A-Bustle.json"))
# operations = ['concat', 'replace', 'upper', 'lower', 'Substr', 'IndexOf', 'Length', 'CharAt', '+', '-', '*', '/', '%', 'Contain', 'Equal', 'if', 'then', 'else', 'SuffixOf', 'PrefixOf', 'StrToInt', 'IntToStr', 'stip', 'title']
# json_result = call_parser('A-Bustle', json_data, operations)

# # # save the json to a file
# # with open('A-Bustle-size.json', 'w') as f:
# #     json.dump(json_result, f)


# # A-Bee
# json_data = json.load(open("A-Bee.json"))
# operations = ['concat', 'replace', 'upper', 'lower', 'Substr', 'IndexOf', 'Length', 'CharAt', '+', '-', '*', '/', '%', 'Contain', 'Equal', 'if', 'then', 'else', 'SuffixOf', 'PrefixOf', 'StrToInt', 'IntToStr', 'stip', 'title']
# json_result = call_parser('A-Bee', json_data, operations)

# # # save the json to a file
# # with open('A-Bee-size.json', 'w') as f:
# #     json.dump(json_result, f)
    

# # A-CB
# json_data = json.load(open("A-CB.json"))
# operations = [
#       'Add',
#       'Concatenate',
#       'Find',
#       'Left',
#       'Len',
#       'Mid',
#       'Minus',
#       'Replace',
#       'Right',
#       'Trim',
#       'Lower',
#       'Upper',
#       'Proper',
#       'Rept',
#       'Substitute',
#       'ToText',
#       'If',
#       'Exact',
#       'Gt',
#       'Gte',
#   ]
# json_result = call_parser('A-CB', json_data, operations)

# # # save the json to a file
# # with open('A-CB-size.json', 'w') as f:
# #     json.dump(json_result, f)
# Out:
# Operators: ['Substr', '-', '+', 'IndexOf', '-', '+', 'IndexOf', '+', '+', '+']
# Operands: ['_arg_0', '(', '1', '_arg_0', '(', '"."', ')', '(', '1', '_arg_0', '"."', ')', '1', '(', '1', '1', ')', ')']
# Operators: ['name', '-']
# Operands: ['0', '3']
# Operators: ['replace', '*', 'Length', '-', 'Length', 'strip']
# Operands: ['_arg_0', '"/"', '" "', '_arg_0', '(', ')', 'length', '_arg_0']
# Operators: ['Substr', '+', 'IndexOf', 'strip']
# Operands: ['name', '1', '1', 'name', '(', '" "', ')']
# Operators: ['-', '-', '+', '+']
# Operands: ['_arg_0', '1', 'length', '1', '(', '1', '1', ')']
# Operators: ['replace', 'IndexOf', '+', '+', 'replace', 'IndexOf', '+']
# Operands: ['_arg_0', '" "', '""', '_arg_0', '" "', '" "', '_arg_0', '" "', '""', '_arg_0', '" "', '0']
# Operators: ['concat', 'concat', 'IndexOf', '-', 'Length']
# Operands: ['_arg_0', '(', '","', '_arg_0', '_arg_0', '(', '","', ')', ')', 'length', '_arg_0']
# Operators: ['replace', '*', 'Length', '-', 'Length', 'strip']
# Operands: ['_arg_0', '" "', '" "', '_arg_0', '(', ')', 'length', '_arg_0']
# Operators: ['replace', '*', 'Length', '-', 'Length', 'strip']
# Operands: ['_arg_0', '"/n"', '" "', '_arg_0', '(', ')', 'length', '_arg_0']
# Operators: ['+', '+', '+', 'IndexOf']
# Operands: ['_arg_0', '1', '" "', '_arg_0', '1', '_arg_0', '" "']
# Operators: ['replace', '*', 'Length', '-', 'Length', 'strip']
# Operands: ['_arg_0', '"="', '" "', '_arg_0', '(', ')', 'length', '_arg_0']
# Operators: ['concat', 'concat', 'concat']
# Operands: ['col1', '(', '","', '(', '" "', 'col2', ')', ')']
# Operators: ['-']
# Operands: ['name', 'length', '3']
# Operators: ['concat', 'concat', 'concat']
# Operands: ['_arg_0', '1', '(', '_arg_1', '(', '"_"', '_arg_2', ')', ')']
# Operators: []
# Operands: ['name', '3']
# Operators: ['Substr', 'IndexOf', 'IndexOf', '+', 'Length', 'strip']
# Operands: ['name', 'name', '(', '" "', 'name', '" "', 'name', ')']
# Operators: ['IndexOf', 'strip']
# Operands: ['_arg_0', '_arg_0', '"-"']
# Operators: ['IndexOf']
# Operands: ['_arg_0', '_arg_0', '"."']
# Operators: ['concat', 'concat', 'concat', 'concat']
# Operands: ['_arg_0', '(', '"/n"', '(', '_arg_1', '(', '"/n"', '_arg_2', ')', ')', ')']
# Operators: ['IndexOf', '-']
# Operands: ['name', 'name', '"-"', 'length', '3']
# Operators: ['-', '+', '+']
# Operands: ['_arg_0', 'length', '2', '(', '4', '4', ')']
# Operators: ['replace', 'IndexOf']
# Operands: ['_arg_0', '_arg_0', '" "', '_arg_0', '_arg_0']
# Operators: ['-', 'IndexOf', 'strip']
# Operands: ['_arg_0', 'length', '_arg_0', '" "']
# Operators: ['replace', 'replace', 'strip']
# Operands: ['_arg_0', '"US"', '""', '"CAN"', '""']
# Operators: ['-', 'concat', '-', 'IntToStr', '-', 'IntToStr', 'Length']
# Operands: ['_arg_0', 'length', '1', '(', '1', ')']
# Operators: ['_arg_0', '+', '+', '+', '_arg_0', '+', '+', '+', '+']
# Operands: ['1', '1', '""', '1', '1', '1', '(', '1', '1', ')']
# Operators: ['replace', 'concat', 'concat']
# Operands: ['_arg_0', '(', '"<"', '(', '"b"', '">"', ')', '""', ')']
# Operators: ['replace']
# Operands: ['_arg_0', '"-"', '""']
# Operators: ['replace']
# Operands: ['_arg_0', '"-"', '""']
# Operators: ['replace', 'replace', 'Substr', '+', 'Length']
# Operands: ['name', '" "', '"-"', '"-"', '"."', '1', '1', 'name', '(', ')']
# Operators: ['concat', 'concat', 'IndexOf']
# Operands: ['"Dr."', '(', '" "', 'name', 'name', '(', '" "', ')', ')']
# Operators: ['concat', 'IndexOf']
# Operands: ['_arg_0', '_arg_0', '"|"', '"|"']
# Operators: ['concat', 'concat']
# Operands: ['_arg_0', '(', '" "', '_arg_1', ')']
# Operators: ['replace', 'strip']
# Operands: ['_arg_0', '_arg_1', 'strip', '(', '""', ')']
# Operators: ['replace', 'replace', 'replace']
# Operands: ['_arg_0', '"BRD"', '"Branding"', '"DRS"', '"Direct Response"', '"LDS"', '"Leads"']
# Operators: ['concat', '+', '+', '+', 'IndexOf', '+']
# Operands: ['name', '1', '"."', 'name', '1', 'name', '(', '" "', '(', '1', '2', ')', '"."', ')']
# Operators: ['-', '+']
# Operands: ['name', 'length', '2', '5', '3']
# Operators: ['concat', 'concat']
# Operands: ['_arg_1', '1', '(', '_arg_0', '"_acme.com"', ')']
# Operators: ['IndexOf', 'concat', 'Length']
# Operands: ['_arg_0', '_arg_0', '" "', '(', '"ssp."', '"ssp."', ')']
# Operators: ['replace', 'replace']
# Operands: ['_arg_0', '_arg_0', '(', '_arg_2', 'strip', '(', '""', ')', '_arg_1', ')']
# Operators: ['concat', 'concat', 'concat', 'concat']
# Operands: ['lastname', '(', '","', '(', '" "', '(', 'firstname', '1', '"."', ')', ')', ')']
# Operators: ['-', 'IndexOf', 'replace']
# Operands: ['_arg_0', 'length', '_arg_0', '"."', '"."', '""']
# Operators: ['concat', 'IndexOf', '+', 'Length']
# Operands: ['_arg_0', '_arg_0', '" "', '" "', '(', '1', '"Company"', '(', ')', ')']
# Operators: ['if', 'Equal', 'then', 'else']
# Operands: ['(', '_arg_0', '_arg_1', '_arg_0', '_arg_2', ')']
# Operators: ['Substr', 'concat', '-', 'IntToStr', 'IndexOf', 'concat', '-', 'IntToStr', 'IndexOf', '+', 'Length']
# Operands: ['_arg_0', '(', '1', '(', '_arg_0', ')', '"="', '1', '(', '_arg_0', ')', '"="', '_arg_0', ')']
# Operators: ['Substr', 'replace', 'IndexOf', 'replace', 'IndexOf', '+', 'Length']
# Operands: ['_arg_0', '_arg_0', '(', '" "', '_arg_0', '"9"', '_arg_0', '" "', '_arg_0', '"9"', '_arg_0', ')']
# Operators: ['Substr', 'IndexOf', '-', 'IndexOf', '-', '+', '+', 'IndexOf']
# Operands: ['_arg_0', '(', '_arg_0', '(', '"_"', '4', ')', '(', '_arg_0', '"_"', '4', ')', '2', '_arg_0', '(', '"_"', ')', ')']
# Operators: ['_arg_0', '-', '+', 'IndexOf']
# Operands: ['1', '_arg_0', '(', '"1"', ')']
# Operators: ['replace', 'replace']
# Operands: ['_arg_0', '"<"', '""', '">"', '""']
# Operators: ['replace']
# Operands: ['name', '"-"', '"."']
# Operators: ['IndexOf', 'strip']
# Operands: ['_arg_0', '_arg_0', '"Inc"']
# Operators: ['IndexOf']
# Operands: ['name', 'name', '" "']
# Operators: ['Substr', 'replace', '-', 'IntToStr', 'IndexOf', 'replace', '-', 'IntToStr', 'IndexOf', '+']
# Operands: ['_arg_0', '_arg_0', '(', '" "', '1', '(', '1', ')', '" "', '_arg_0', '" "', '1', '(', '1', ')', '" "', '4', ')']
# Operators: ['Substr', 'IndexOf', 'IndexOf', '+', 'Length', 'strip']
# Operands: ['_arg_0', '_arg_0', '(', '" "', '_arg_0', '" "', '_arg_0', ')']
# Operators: ['-']
# Operands: ['name', 'length', '3']
# Operators: ['replace']
# Operands: ['_arg_0', '_arg_1', 'strip', '(', '""', ')']
# Operators: ['replace', 'replace', '-']
# Operands: ['_arg_0', '"<"', '" "', '","', '" "', '1']
# Operators: ['Substr', 'IndexOf', 'IndexOf', '+', 'replace', 'IndexOf', 'strip']
# Operands: ['_arg_0', '_arg_0', '(', '"_"', '_arg_0', '"_"', '_arg_0', '_arg_0', '1', '""', '"_"', ')']
# Operators: ['concat', 'concat']
# Operands: ['firstname', '(', '" "', 'lastname', ')']
# Operators: ['Substr', '+', 'IndexOf', '+', 'IndexOf', '+', 'Length']
# Operands: ['_arg_1', '(', '1', '_arg_1', '(', '"_"', ')', '(', '1', '_arg_1', '"_"', ')', '_arg_1', ')']
# Operators: ['concat', 'concat', 'concat']
# Operands: ['firstname', '1', '(', '"."', '(', '" "', 'lastname', ')', ')']
# Operators: ['replace', 'if', 'Equal', 'then', 'else']
# Operands: ['_arg_0', '"that"', '(', '(', '"that"', '_arg_0', '"that"', '""', ')', ')']
# Operators: ['_arg_0', '-', '-', 'concat', 'Length', 'strip']
# Operands: ['1', '(', '"in"', '"in"', ')']
# Operators: ['Substr', 'concat', '-', 'IntToStr', 'IndexOf', 'concat', '-', 'IntToStr', 'IndexOf', '+', 'Length']
# Operands: ['_arg_0', '(', '1', '(', '_arg_0', ')', '"/"', '1', '(', '_arg_0', ')', '"/"', '_arg_0', ')']
# Operators: ['concat', 'concat', 'concat']
# Operands: ['firstname', '(', '" "', '(', 'lastname', '1', '"."', ')', ')']
# Operators: ['concat', 'concat']
# Operands: ['lastname', '(', '" "', 'firstname', ')']
# Operators: ['IndexOf']
# Operands: ['_arg_1', '_arg_1', '"_"']
# Operators: ['replace']
# Operands: ['_arg_0', '" "', '"-"']
# Operators: ['Substr', '+']
# Operands: ['name', '4', '4', '3']
# Operators: ['replace', 'lower']
# Operands: ['_arg_0', '_arg_0', '(', '_arg_1', ')']
# Operators: ['concat', '+', 'concat', '+', '+']
# Operands: ['"("', 'name', '3', '(', '")"', '" "', 'name', '3', '1', ')']
# Operators: ['replace', '*', 'Length', '-', 'Length', 'strip']
# Operands: ['_arg_0', '"/"', '" "', '_arg_0', '(', ')', 'length', '_arg_0']
# Operators: ['Substr', 'concat', '-', 'IntToStr', 'IndexOf', 'concat', '-', 'IntToStr', 'IndexOf', '+', 'Length']
# Operands: ['_arg_0', '(', '1', '(', '_arg_0', ')', '"_"', '1', '(', '_arg_0', ')', '"_"', '_arg_0', ')']
# Operators: ['IndexOf']
# Operands: ['_arg_0', '_arg_0', '" "']
# Operators: ['replace', '-', '+']
# Operands: ['arg_0', '"-"', '"/"', 'length', '1', '4']
# Operators: ['concat', 'replace', 'concat']
# Operands: ['arg_0', '15', '"..."', '(', 'arg_0', '"..."', 'arg_0', ')']
# Operators: ['arg_0', '-', 'Length']
# Operands: ['0', 'arg_1', '(', ')']
# Operators: ['concat', '-', '-', 'concat', '+', '+', 'concat', '+']
# Operands: ['arg_0', '4', 'length', '2', '(', '"/"', 'arg_0', '3', '"/"', '"/"', 'arg_0', '3', '2', ')']
# Operators: ['if', 'Equal', 'then', 'else']
# Operands: ['(', '"NONE"', 'arg_0', 'arg_1', 'arg_0', ')']
# Operators: ['Substr', 'IndexOf', '+', 'IndexOf', '+', '+']
# Operands: ['arg_0', 'arg_0', '(', '"/"', '(', '4', '4', ')', 'arg_0', '"/"', '(', '4', '4', ')', '15', ')']
# Operators: ['if', 'Length', 'Length', 'then', 'else']
# Operands: ['(', 'arg_1', 'arg_0', 'arg_1', 'arg_0', ')']
# Operators: ['if', 'Equal', 'lower', 'lower', 'then', 'else']
# Operands: ['(', 'arg_0', '(', 'arg_1', ')', '"yes"', '"no"', ')']
# Operators: ['if', 'Equal', 'lower', 'then', 'else']
# Operands: ['(', 'arg_0', 'arg_0', '(', ')', '"true"', '"false"', ')']
# Operators: ['lower', 'replace', 'upper']
# Operands: ['arg_0', 'arg_0', '15', 'arg_0', '(', ')']
# Operators: ['replace']
# Operands: ['arg_0', '"-"', '"/"']
# Operators: ['+', '+', '+', 'IndexOf']
# Operands: ['arg_0', '1', '""', 'arg_0', '1', 'arg_0', '" "', '2']
# Operators: ['Length', 'IntToStr']
# Operands: ['arg_0']
# Operators: ['Substr', 'IndexOf', 'IndexOf', '+', 'strip']
# Operands: ['arg_0', 'arg_0', '(', '" "', 'arg_0', '" "', '15', ')']
# Operators: ['IndexOf']
# Operands: ['arg_1', 'arg_1', '" "']
# Operators: ['replace']
# Operands: ['arg_0', '"com"', '"org"', '1']
# Operators: ['if', 'Equal', 'then', 'else']
# Operands: ['(', 'arg_0', 'arg_1', '"yes"', '"no"', ')']
# Operators: ['Length', 'replace', 'Length']
# Operands: ['arg_0', 'arg_0', 'arg_1', 'strip', '(', '""', ')']
# Operators: ['concat', 'Substr', 'IndexOf', 'IndexOf', '+', 'strip']
# Operands: ['"Mr. "', 'arg_0', '(', 'arg_0', '(', '" "', 'arg_0', '" "', '15', ')', ')']
# Operators: ['concat', 'replace', 'replace', 'concat']
# Operands: ['arg_0', '(', '"-"', '"("', '")"', ')', '(', 'arg_0', '")"', 'arg_0', ')']
# Operators: ['lower', 'strip']
# Operands: ['arg_0']
# Operators: ['concat', 'title', '-', 'upper', '-']
# Operands: ['arg_0', '(', '4', 'arg_0', 'length', '4', ')']
# Operators: ['Length', '-', 'replace', 'Length', 'IntToStr']
# Operands: ['(', 'arg_0', 'arg_0', '"/"', '""', ')']
# Operators: ['concat', 'replace', 'concat']
# Operands: ['"+"', 'arg_0', '(', '"+"', '"-"', '"-"', ')']
# Operators: ['replace']
# Operands: ['arg_0', '"<COMPANY>"', 'arg_1']
# Operators: ['title', '+', 'lower', 'Substr', '+', '+', 'title', '+']
# Operands: ['arg_0', '1', 'arg_0', '1', '1', '15', 'arg_0', '1', '15']
# Operators: ['Length', 'concat', 'lower', 'IndexOf', 'lower']
# Operands: ['arg_0', 'arg_0', '(', 'arg_1', ')', 'arg_1', '(', ')']
# Operators: ['concat', '*', '-', '+']
# Operands: ['"0"', '4', 'arg_0', 'length', '1', '4']
# Operators: ['concat', '-', 'if', 'Equal', 'then', 'else']
# Operands: ['arg_0', '3', '(', '(', '"morning"', 'arg_1', '" AM"', '" PM"', ')', ')']
# Operators: ['upper', '+', '+', 'upper', '+', 'IndexOf']
# Operands: ['arg_0', '1', '""', 'arg_0', '1', 'arg_0', '" "', '2']
# Operators: ['replace', 'replace', 'concat']
# Operands: ['arg_0', 'arg_0', '(', '"."', '""', 'arg_0', '".0"', ')']
# Operators: ['Substr', 'Length', 'Length', '+']
# Operands: ['arg_0', 'arg_1', '(', 'arg_1', '15', ')']

# %%
# process results_bus
from numpy import NaN
import pandas as pd
import json
result_df_38 = pd.DataFrame(columns=['Iteration', 'BUS', 'A-BUS', 'A-Bustle', 'A-Bustle_std', 'A-Bee', 'A-Bee_std', 'A-CB', 'A-CB_std'])
result_df_89 = pd.DataFrame(columns=['Iteration', 'BUS', 'A-BUS', 'A-Bustle', 'A-Bustle_std', 'A-Bee', 'A-Bee_std', 'A-CB', 'A-CB_std'])
results = []
algos = ['BUS', 'A-BUS', 'A-Bustle', 'A-Bee', 'A-CB']

for alg in algos:
    results.append(json.load(open(alg + '-size.json')))


for pIndex in range(len(algos)):
    for key, value in results[pIndex].items():
        df = pd.DataFrame(columns=['Iteration', 'Program', 'Size'])
        if pIndex == 0 or pIndex == 1:
            # Create a list of dictionaries
            rows = [{'Iteration': item['Iteration'], 
                    'Program': item['Program'], 
                    'Size': int(item['Size'])} for item in value]
            # Convert list of dictionaries to DataFrame and append it
            df = pd.concat([df, pd.DataFrame(rows)], ignore_index=True)
        else:
            for run in ['1', '2', '3', '4', '5']:
                for item in value[run]:
                    # Create a list of dictionaries
                    rows = [{'Iteration': item['Iteration'], 
                            'Program': item['Program'], 
                            'Size': int(item['Size'])} for item in value[run]]
                    # Convert list of dictionaries to DataFrame and append it
                    df = pd.concat([df, pd.DataFrame(rows)], ignore_index=True)
            
        max_iter = df['Iteration'].max()
        for i in range(1, (5 if key == '38' else 12)):
            # add the iteration column to the result_df
            if key == '89':
                result_df_89.loc[i-1, 'Iteration'] = i
            else:
                result_df_38.loc[i-1, 'Iteration'] = i
        
        for i in range(1, (5 if key == '38' else 12)):
            if algos[pIndex] == 'A-BUS' or algos[pIndex] == 'BUS':
                avg_size = df[df['Iteration'] == i]['Size'].mean()
                # at ith row ( 1 indexed) add the average size
                if key == '89':
                    result_df_89.loc[i-1, algos[pIndex]] = avg_size
                else:
                    result_df_38.loc[i-1, algos[pIndex]] = avg_size
            else:
                avg_size = df[df['Iteration'] == i]['Size'].mean()
                std_size = df[df['Iteration'] == i]['Size'].std()
                # at ith row ( 1 indexed) add the average size
                if key == '89':
                    result_df_89.loc[i-1, algos[pIndex]] = avg_size
                    result_df_89.loc[i-1, algos[pIndex] + '_std'] = std_size
                else:
                    result_df_38.loc[i-1, algos[pIndex]] = avg_size
                    result_df_38.loc[i-1, algos[pIndex] + '_std'] = std_size                

# do ffill for the NaN values
result_df_38.fillna(method='ffill', inplace=True)
result_df_89.fillna(method='ffill', inplace=True)

print(result_df_38)
print(result_df_89)
# Out:
#    Iteration     BUS      A-BUS   A-Bustle  A-Bustle_std      A-Bee  \
# 0          1  8.8125   8.357143   9.322873      4.199974   9.892322
# 1          2  8.8125  20.250000  33.082278     16.145424  26.181818
# 2          3  8.8125  20.250000  33.082278     16.145424  59.190476
# 3          4  8.8125  20.250000  33.082278     16.145424  54.500000
#
#    A-Bee_std       A-CB   A-CB_std
# 0   3.620829   9.320484   3.828605
# 1   7.939725  21.698769   8.868376
# 2  12.094863  47.458840  20.867828
# 3  12.602043  47.458840  20.867828
#     Iteration       BUS      A-BUS    A-Bustle  A-Bustle_std       A-Bee  \
# 0           1  9.297297   9.069444   10.824171      6.806589   10.732047
# 1           2  9.297297  29.222222   37.094945     26.092503   33.090613
# 2           3  9.297297  29.222222   37.094945     26.092503  168.020253
# 3           4  9.297297  68.250000   84.251220     44.763194   98.000000
# 4           5  9.297297  68.250000   84.251220     44.763194   98.000000
# 5           6  9.297297  68.250000   84.251220     44.763194   98.000000
# 6           7  9.297297  59.000000  140.931677     91.783722   98.000000
# 7           8  9.297297  59.000000  140.931677     91.783722   98.000000
# 8           9  9.297297  59.000000  140.931677     91.783722   98.000000
# 9          10  9.297297  59.000000  140.931677     91.783722   98.000000
# 10         11  9.297297  83.000000  140.931677     91.783722   98.000000
#
#      A-Bee_std       A-CB   A-CB_std
# 0     4.345413   7.964623   3.317163
# 1    10.539978  25.301255  14.349952
# 2   105.501000  50.919492  50.677009
# 3    23.807849  76.046893  26.679944
# 4    23.807849  76.046893  26.679944
# 5    23.807849  76.046893  26.679944
# 6    23.807849  76.046893  26.679944
# 7    23.807849  76.046893  26.679944
# 8    23.807849  76.046893  26.679944
# 9    23.807849  76.046893  26.679944
# 10   23.807849  76.046893  26.679944

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import matplotlib
import pandas as pd
import numpy as np

# Set Matplotlib to use LaTeX for rendering
matplotlib.use('pgf')
matplotlib.rcParams.update({
    'pgf.texsystem': 'pdflatex',
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})

NUMBER_TICKS = 6
NUMBER_TICKS_Y = 8

algos = ['A-BUS', 'BUS']#, 'A-Bustle', 'A-Bee', 'A-CB']

def plot_benchmark(ax, df, benchmark_name, labels, line_styles):
    ax.set_title(f'{benchmark_name} Benchmark', fontsize=16)

    for index, column in enumerate(algos):
        style = line_styles[index]
        label = labels[index]

        # Plot the line and capture the color
        line = ax.plot(df['Iteration'], df[column], label=label, linestyle=style)
        line_color = line[0].get_color()  # Get the color of the line

        # Apply fill_between with the same color for columns except 'A-BUS'
        if column != 'A-BUS' and column != 'BUS':
            ax.fill_between(df['Iteration'], 
                            df[column] - df[column + '_std'], 
                            df[column] + df[column + '_std'], 
                            alpha=0.2, 
                            color=line_color)


    # Set plot limits, labels, and other configurations
    y_start = 0 if benchmark_name == 'SyGuS' else 0
    y_end = 100 if benchmark_name == 'SyGuS' else 30
    ax.set_ylim(y_start, y_end)
    ax.set_xticks(np.linspace(df['Iteration'].min(), df['Iteration'].max(), NUMBER_TICKS, dtype=int))
    y_ticks = np.linspace(y_start, y_end, NUMBER_TICKS_Y, dtype=int)
    ax.set_yticks(y_ticks)

    ax.tick_params(axis='both', which='major', labelsize=10)
    ax.margins(x=0.12, y=0.12)
    if benchmark_name == 'SyGuS':
        ax.legend(loc='upper right', fontsize=8, ncol=2)
    else:
        ax.legend(loc='lower right', fontsize=8, ncol=2)
    ax.set_xlabel("Number of Iterations", fontsize=10)
    if benchmark_name == 'SyGuS':
        ax.set_ylabel("Average Program Size", fontsize=10)
    # ax.set_ylabel("Average Program Size", fontsize=10)
    ax.grid(False)

def main():
    # Prepare the plotting data
    labels = [r"A-BUS", r"BUS"]#, r"A-Bustle", r"A-Bee", r"A-CB"]
    line_styles = [(0, (5, 5)), 'solid', (0, (5, 1)), (0, (3, 1, 1, 1))]

    # Define the figure size and DPI
    px = 1/plt.rcParams['figure.dpi']
    fig, axs = plt.subplots(1, 2, figsize=(620*px, 270*px), 
                            gridspec_kw={'hspace': 0.35, 'wspace': 0.14, 'bottom':0.15, 'left':0.089, 'right':0.99, 'top':0.85})

    plot_benchmark(axs[0], result_df_89, 'SyGuS', labels, line_styles)
    plot_benchmark(axs[1], result_df_38, '38', labels, line_styles)

    # Save the figure
    plt.savefig("./average_program_size_A-BUS_BUS.pdf")

if __name__ == "__main__":
    main()
